# %%
from pathlib import Path
import pandas as pd
import xlwings as xw
import numpy as np
import matplotlib.pyplot as plt
from rdp import rdp

# %%
#Access input folder
input_dir1 = Path ("G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets")
print ("1",input_dir1)

#Access folders inside input folder
input_dir2 =  [folder for folder in input_dir1.iterdir() if folder.is_dir()]
print ("2",input_dir2)

# Create output directory
output_dir1 = Path("G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets_reduced")
output_dir1.mkdir(exist_ok = True)

# Define current work directory
current_dir = Path.cwd()

# Access the template to be used to generate files
excel_template = current_dir/ "Template.xlsx"

# Mapping dictionary
mapping = {"1": 0, "2": 15, "3": 30, "4": 45, "5": 60}
# Out:
# 1 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets
# 2 [WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr05m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr07m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr09m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr11m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr13m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr15m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr17m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr19m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr21m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr23m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr25m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr27m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr29m'), WindowsPath('G:/Chamodi/LSDYNA3D/RP_TH_models/RP_section_datasets/RP_curves_fr30m')]

# %%
def reduce_points(time, pressure, file1):
    
    zero_crossing_index = next((i for i, val in enumerate(pressure[:], start=0) if val <= 0), None)
    
    # Combine time and pressure into a single array of 2D points
    points = np.column_stack((time, pressure))
    
    segment1 = points[:zero_crossing_index]  # Example segmentation
    segment2 = points[zero_crossing_index:]
    
    reduced_segment1 = rdp(segment1, epsilon=0.001)
    reduced_segment2 = rdp(segment2, epsilon=0.05)
    
    reduced_points = np.vstack((reduced_segment1, reduced_segment2))
    
    # Separate the reduced points into time and pressure
    reduced_time = reduced_points[:, 0]
    reduced_pressure = reduced_points[:, 1]
    
    # Plot the original and reduced data
    plt.figure(figsize=(4, 4))
    plt.plot(time, pressure, label='Original Data', alpha=0.5)
    plt.plot(reduced_time, reduced_pressure, label='Reduced Data', marker='o')
    plt.xlabel('Time')
    plt.ylabel('Pressure')
    plt.legend()
    
    # Save the plot as an image
    plt.savefig(output_dir3/f'{file1.name}_reduced.png', dpi=150, bbox_inches='tight', facecolor='white')
        
    # Close the plot to free up memory
    plt.close()
    
    return reduced_time, reduced_pressure

# %%
def get_phase_array(time, pressure, CT, CP, TT, TP):
    a=0
    b=0
    phase = []
    for t, p in zip(time, pressure):
        if round (t, 10) < round (CT, 10):
            phase.append('positive')#{t} {change_time}')
        elif round (CT, 10) <= round (t, 10) < round(TT, 10):
            a+=1
            if a == 1 and abs(p - CP) <0.000001:
                phase.append('negative_increasing')
            elif a == 1 and abs(p - CP) >0.000001:
                phase.append('error')
                print (f'error- p={p} , change p ={CP}, t ={t}, change t = {CT}')
            else:
                phase.append('negative_increasing')# {t} {trough_time}')
    
        elif round (TT, 10) <= round (t, 10):
            b+=1
            if b == 1 and abs(p - TP) < 0.000001:
                phase.append('negative_decreasing')
            elif b == 1 and abs(p - TP) > 0.000001:
                phase.append('error')
                print (f'error- p={p} , trough p ={TP}, t ={t}, trough t = {TT}')
            else:
                phase.append('negative_decreasing')
        else:
            phase.append('something wrong')
            print ('something wrong')
                
    return phase

# %%
def find_CTE(reduced_pressure, reduced_time, file1, EM, SD, A):
    
    lowest_index2 = np.argmin(reduced_pressure[:])
    # TROUGH
    TT = reduced_time[lowest_index2]
    TP = reduced_pressure[lowest_index2]
    
    # Find the first zero crossing between peak and lowest value
    zero_crossing_index_1 = next((i for i, val in enumerate(reduced_pressure[:lowest_index2], start=0) if val <= 0), None)
    
    # CHANGE AND END
    CT = reduced_time[zero_crossing_index_1]
    CP = reduced_pressure[zero_crossing_index_1]
    ET = reduced_time[-1]
    EP = reduced_pressure[-1]

    
    phase = get_phase_array(reduced_time, reduced_pressure, CT, CP, TT, TP)
    
    print (zero_crossing_index_1, lowest_index2)
    print('phase len', len(phase))
    
    # Create a dictionary with the arrays
    data = {"Mass": [EM] * len(reduced_time),
             "Standoff distance": [SD] * len(reduced_time),
             "Angle": [A] * len(reduced_time),
             'Time': reduced_time,
             "Phase": phase,
             'Pressure': reduced_pressure}
    
    # Create DataFrames from dictionaries
    df2 = pd.DataFrame(data)
    
    # Initiate xlwings library
    with xw.App (visible = False) as app:
        
        wb = app.books.open(excel_template)
        # Write dataframe in excel template
        wb.sheets[0].range("A1").options(index=False).value = df2
        
        # Create files in output directory
        wb.save(output_dir3/f"{file1.name}.xlsx")
    
    print ("file_name",file1.name)
    
    return TT, TP, CT, CP, ET, EP

# %%
df_all = pd.DataFrame(columns=["Mass", "Standoff distance", "Angle", "Arrival time", "AP", "Change time", "CP", "Trough time", "TP", "End time", "EP","Original", "Reduced" ])

for folder1 in input_dir2: # folder1-RP_curves_fr05m

    input_dir3 =  [folder2 for folder2 in folder1.iterdir() if folder2.is_dir()]
    # Create output folders
    output_dir2 = output_dir1/ folder1.name
    output_dir2.mkdir(exist_ok = True)
    print ("OUTPUT 2", output_dir2)
    
    for folder2 in input_dir3: # folder2-05m00.5kg
        # SD AND EM
        SD = int(folder2.name[0:2])
        EM = float(folder2.name[3:-2])
        
        # Create output folders
        output_dir3 = output_dir2/ folder2.name
        output_dir3.mkdir(exist_ok = True)
        print ("OUTPUT 3", output_dir3)
        
        # Make a list of data file names
        excel_files = list(folder2.rglob("*.xlsx"))
        
        # Access each file 
        for file1 in excel_files: # file-1.xlsx
            
            # Assign value to A based on file.stem
            file_name = file1.stem
            A = mapping.get(file_name, None)
            
            # Read data from Excel file
            df1 = pd.read_excel(file1)
            
            # Extract time and pressure columns
            time = df1["Time"].dropna().values
            pressure = df1["Pressure"].dropna().values

            # ARRIVAL
            AT = time[0]
            AP = pressure[0]
                    
            reduced_time, reduced_pressure = reduce_points(time, pressure, file1)
    
            TT, TP, CT, CP, ET, EP = find_CTE(reduced_pressure, reduced_time, file1, EM, SD, A)
                

            # Creating a new DataFrame to append
            row_all = pd.DataFrame({"Mass": [EM], "Standoff distance": [SD], "Angle": [A],
                                    "Arrival time": [AT],"AP": [AP],
                                    "Change time": [CT], "CP": [CP],
                                    "Trough time": [TT], "TP": [TP],
                                    "End time": [ET], "EP": [EP],
                                    "Original":[len(pressure)], "Reduced": [len(reduced_pressure)]})
            df_all = pd.concat([df_all, row_all], ignore_index=True)

            # Create the plot
            plt.figure(figsize=(4, 4))
            plt.plot(time, pressure, color='b', linestyle=':')
            plt.plot(reduced_time, reduced_pressure, color='r', linestyle='-', marker='o')
            # Save the plot as an image
            plt.savefig(output_dir3/f'{file1.name}.png', dpi=150, bbox_inches='tight', facecolor='white')
                
            # Close the plot to free up memory
            plt.close()
# Out:
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m00.5kg
# 26 28
# phase len 56
# file_name 1.xlsx
# 42 48
# phase len 65
# file_name 2.xlsx
# 45 53
# phase len 64
# file_name 3.xlsx
# 47 57
# phase len 78
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m02.5kg
# 39 42
# phase len 50
# file_name 1.xlsx
# 63 66
# phase len 76
# file_name 2.xlsx
# 90 95
# phase len 98
# file_name 3.xlsx
# 58 72
# phase len 84
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m04.5kg
# 143 146
# phase len 148
# file_name 1.xlsx
# 70 71
# phase len 82
# file_name 2.xlsx
# 82 87
# phase len 89
# file_name 3.xlsx
# 65 80
# phase len 84
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m06.5kg
# 224 228
# phase len 231
# file_name 1.xlsx
# 71 79
# phase len 94
# file_name 2.xlsx
# 88 92
# phase len 95
# file_name 3.xlsx
# 112 121
# phase len 123
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m08.5kg
# 260 264
# phase len 270
# file_name 1.xlsx
# 75 87
# phase len 103
# file_name 2.xlsx
# 99 104
# phase len 132
# file_name 3.xlsx
# 111 118
# phase len 123
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m10.5kg
# 243 244
# phase len 252
# file_name 1.xlsx
# 79 92
# phase len 100
# file_name 2.xlsx
# 93 98
# phase len 123
# file_name 3.xlsx
# 104 115
# phase len 119
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m12.5kg
# 203 204
# phase len 214
# file_name 1.xlsx
# 78 81
# phase len 99
# file_name 2.xlsx
# 95 101
# phase len 127
# file_name 3.xlsx
# 107 112
# phase len 115
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m14.5kg
# 243 244
# phase len 247
# file_name 1.xlsx
# 83 101
# phase len 129
# file_name 2.xlsx
# 85 90
# phase len 119
# file_name 3.xlsx
# 121 124
# phase len 126
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m16.5kg
# 202 203
# phase len 206
# file_name 1.xlsx
# 82 85
# phase len 90
# file_name 2.xlsx
# 93 106
# phase len 132
# file_name 3.xlsx
# 147 149
# phase len 151
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m18.5kg
# 179 180
# phase len 183
# file_name 1.xlsx
# 77 80
# phase len 84
# file_name 2.xlsx
# 77 94
# phase len 113
# file_name 3.xlsx
# 172 173
# phase len 175
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m20.5kg
# 176 177
# phase len 180
# file_name 1.xlsx
# 87 90
# phase len 94
# file_name 2.xlsx
# 76 94
# phase len 117
# file_name 3.xlsx
# 173 175
# phase len 177
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m22.5kg
# 196 197
# phase len 200
# file_name 1.xlsx
# 76 79
# phase len 83
# file_name 2.xlsx
# 84 102
# phase len 122
# file_name 3.xlsx
# 146 164
# phase len 166
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m24.5kg
# 170 171
# phase len 174
# file_name 1.xlsx
# 79 82
# phase len 86
# file_name 2.xlsx
# 85 100
# phase len 114
# file_name 3.xlsx
# 157 178
# phase len 182
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m26.5kg
# 223 224
# phase len 227
# file_name 1.xlsx
# 72 76
# phase len 80
# file_name 2.xlsx
# 84 102
# phase len 117
# file_name 3.xlsx
# 167 185
# phase len 190
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m28.5kg
# 163 164
# phase len 166
# file_name 1.xlsx
# 77 82
# phase len 86
# file_name 2.xlsx
# 84 100
# phase len 118
# file_name 3.xlsx
# 142 165
# phase len 169
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m30.5kg
# 157 158
# phase len 160
# file_name 1.xlsx
# 71 76
# phase len 79
# file_name 2.xlsx
# 86 101
# phase len 119
# file_name 3.xlsx
# 305 307
# phase len 309
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m32.5kg
# 115 120
# phase len 123
# file_name 1.xlsx
# 69 72
# phase len 76
# file_name 2.xlsx
# 84 101
# phase len 121
# file_name 3.xlsx
# 393 394
# phase len 396
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m34.5kg
# 112 146
# phase len 150
# file_name 1.xlsx
# 71 75
# phase len 78
# file_name 2.xlsx
# 82 98
# phase len 119
# file_name 3.xlsx
# 406 407
# phase len 410
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr05m\05m35.0kg
# 30 31
# phase len 34
# file_name 1.xlsx
# 141 151
# phase len 156
# file_name 2.xlsx
# 140 142
# phase len 144
# file_name 3.xlsx
# 160 162
# phase len 165
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m00.5kg
# 23 34
# phase len 36
# file_name 1.xlsx
# 48 56
# phase len 63
# file_name 2.xlsx
# 58 68
# phase len 90
# file_name 3.xlsx
# 70 76
# phase len 87
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m02.5kg
# 113 128
# phase len 137
# file_name 1.xlsx
# 82 85
# phase len 94
# file_name 2.xlsx
# 111 123
# phase len 134
# file_name 3.xlsx
# 50 56
# phase len 69
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m04.5kg
# 61 74
# phase len 79
# file_name 1.xlsx
# 95 97
# phase len 107
# file_name 2.xlsx
# 88 101
# phase len 118
# file_name 3.xlsx
# 43 52
# phase len 65
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m06.5kg
# 95 107
# phase len 111
# file_name 1.xlsx
# 90 93
# phase len 107
# file_name 2.xlsx
# 97 110
# phase len 131
# file_name 3.xlsx
# 43 50
# phase len 67
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m08.5kg
# 96 110
# phase len 114
# file_name 1.xlsx
# 88 90
# phase len 103
# file_name 2.xlsx
# 99 111
# phase len 132
# file_name 3.xlsx
# 48 55
# phase len 71
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m10.5kg
# 129 144
# phase len 146
# file_name 1.xlsx
# 96 98
# phase len 116
# file_name 2.xlsx
# 110 111
# phase len 121
# file_name 3.xlsx
# 120 128
# phase len 147
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m12.5kg
# 139 143
# phase len 146
# file_name 1.xlsx
# 95 97
# phase len 118
# file_name 2.xlsx
# 106 109
# phase len 120
# file_name 3.xlsx
# 107 112
# phase len 116
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m14.5kg
# 146 149
# phase len 152
# file_name 1.xlsx
# 100 111
# phase len 127
# file_name 2.xlsx
# 124 125
# phase len 136
# file_name 3.xlsx
# 100 107
# phase len 110
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m16.5kg
# 155 159
# phase len 161
# file_name 1.xlsx
# 100 114
# phase len 128
# file_name 2.xlsx
# 128 130
# phase len 144
# file_name 3.xlsx
# 101 106
# phase len 111
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m18.5kg
# 92 94
# phase len 100
# file_name 1.xlsx
# 91 104
# phase len 119
# file_name 2.xlsx
# 129 132
# phase len 144
# file_name 3.xlsx
# 100 108
# phase len 110
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m20.5kg
# 145 152
# phase len 154
# file_name 1.xlsx
# 98 115
# phase len 127
# file_name 2.xlsx
# 101 112
# phase len 130
# file_name 3.xlsx
# 107 117
# phase len 119
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m22.5kg
# 164 171
# phase len 173
# file_name 1.xlsx
# 89 105
# phase len 118
# file_name 2.xlsx
# 104 119
# phase len 136
# file_name 3.xlsx
# 98 106
# phase len 108
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m24.5kg
# 214 222
# phase len 224
# file_name 1.xlsx
# 89 107
# phase len 119
# file_name 2.xlsx
# 112 126
# phase len 140
# file_name 3.xlsx
# 97 106
# phase len 108
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m26.5kg
# 131 133
# phase len 141
# file_name 1.xlsx
# 88 107
# phase len 119
# file_name 2.xlsx
# 106 121
# phase len 142
# file_name 3.xlsx
# 225 226
# phase len 230
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m28.5kg
# 137 139
# phase len 142
# file_name 1.xlsx
# 81 99
# phase len 111
# file_name 2.xlsx
# 102 115
# phase len 136
# file_name 3.xlsx
# 218 219
# phase len 223
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m30.5kg
# 140 142
# phase len 145
# file_name 1.xlsx
# 81 100
# phase len 113
# file_name 2.xlsx
# 105 120
# phase len 130
# file_name 3.xlsx
# 104 112
# phase len 115
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m32.5kg
# 160 162
# phase len 165
# file_name 1.xlsx
# 85 108
# phase len 122
# file_name 2.xlsx
# 109 125
# phase len 134
# file_name 3.xlsx
# 112 124
# phase len 127
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m34.5kg
# 157 159
# phase len 162
# file_name 1.xlsx
# 89 112
# phase len 126
# file_name 2.xlsx
# 97 114
# phase len 119
# file_name 3.xlsx
# 111 121
# phase len 124
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr07m\07m35.0kg
# 159 161
# phase len 164
# file_name 1.xlsx
# 91 107
# phase len 120
# file_name 2.xlsx
# 103 117
# phase len 122
# file_name 3.xlsx
# 108 117
# phase len 120
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m00.5kg
# 26 41
# phase len 45
# file_name 1.xlsx
# 81 83
# phase len 91
# file_name 2.xlsx
# 89 93
# phase len 104
# file_name 3.xlsx
# 76 78
# phase len 82
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m02.5kg
# 59 70
# phase len 80
# file_name 1.xlsx
# 100 108
# phase len 121
# file_name 2.xlsx
# 126 132
# phase len 148
# file_name 3.xlsx
# 39 44
# phase len 54
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m04.5kg
# 50 63
# phase len 76
# file_name 1.xlsx
# 107 118
# phase len 133
# file_name 2.xlsx
# 132 137
# phase len 155
# file_name 3.xlsx
# 44 50
# phase len 64
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m06.5kg
# 97 112
# phase len 130
# file_name 1.xlsx
# 104 114
# phase len 132
# file_name 2.xlsx
# 130 141
# phase len 161
# file_name 3.xlsx
# 53 59
# phase len 77
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m08.5kg
# 98 117
# phase len 122
# file_name 1.xlsx
# 106 118
# phase len 136
# file_name 2.xlsx
# 105 115
# phase len 134
# file_name 3.xlsx
# 62 67
# phase len 89
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m10.5kg
# 89 101
# phase len 105
# file_name 1.xlsx
# 118 133
# phase len 156
# file_name 2.xlsx
# 110 119
# phase len 142
# file_name 3.xlsx
# 76 91
# phase len 102
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m12.5kg
# 97 108
# phase len 112
# file_name 1.xlsx
# 113 122
# phase len 149
# file_name 2.xlsx
# 123 131
# phase len 155
# file_name 3.xlsx
# 89 93
# phase len 115
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m14.5kg
# 127 137
# phase len 142
# file_name 1.xlsx
# 115 128
# phase len 160
# file_name 2.xlsx
# 117 126
# phase len 153
# file_name 3.xlsx
# 172 176
# phase len 201
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m16.5kg
# 127 141
# phase len 143
# file_name 1.xlsx
# 128 140
# phase len 167
# file_name 2.xlsx
# 124 133
# phase len 157
# file_name 3.xlsx
# 167 168
# phase len 193
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m18.5kg
# 132 146
# phase len 148
# file_name 1.xlsx
# 133 145
# phase len 179
# file_name 2.xlsx
# 129 137
# phase len 163
# file_name 3.xlsx
# 170 171
# phase len 196
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m20.5kg
# 128 140
# phase len 142
# file_name 1.xlsx
# 139 145
# phase len 155
# file_name 2.xlsx
# 99 107
# phase len 111
# file_name 3.xlsx
# 175 176
# phase len 201
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m22.5kg
# 143 154
# phase len 156
# file_name 1.xlsx
# 141 148
# phase len 156
# file_name 2.xlsx
# 125 140
# phase len 156
# file_name 3.xlsx
# 133 134
# phase len 138
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m24.5kg
# 164 172
# phase len 174
# file_name 1.xlsx
# 148 153
# phase len 161
# file_name 2.xlsx
# 133 149
# phase len 166
# file_name 3.xlsx
# 194 195
# phase len 197
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m26.5kg
# 143 156
# phase len 158
# file_name 1.xlsx
# 156 169
# phase len 187
# file_name 2.xlsx
# 138 152
# phase len 168
# file_name 3.xlsx
# 190 203
# phase len 220
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m28.5kg
# 126 141
# phase len 143
# file_name 1.xlsx
# 112 127
# phase len 143
# file_name 2.xlsx
# 122 135
# phase len 151
# file_name 3.xlsx
# 185 198
# phase len 215
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m30.5kg
# 114 129
# phase len 131
# file_name 1.xlsx
# 116 130
# phase len 151
# file_name 2.xlsx
# 156 170
# phase len 187
# file_name 3.xlsx
# 189 201
# phase len 218
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m32.5kg
# 135 146
# phase len 148
# file_name 1.xlsx
# 129 142
# phase len 160
# file_name 2.xlsx
# 115 133
# phase len 150
# file_name 3.xlsx
# 175 189
# phase len 194
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m34.5kg
# 112 122
# phase len 124
# file_name 1.xlsx
# 124 138
# phase len 157
# file_name 2.xlsx
# 167 181
# phase len 198
# file_name 3.xlsx
# 192 202
# phase len 208
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr09m\09m35.0kg
# 120 131
# phase len 133
# file_name 1.xlsx
# 139 155
# phase len 174
# file_name 2.xlsx
# 170 184
# phase len 203
# file_name 3.xlsx
# 171 181
# phase len 186
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m00.5kg
# 40 41
# phase len 44
# file_name 1.xlsx
# 57 58
# phase len 68
# file_name 2.xlsx
# 56 59
# phase len 66
# file_name 3.xlsx
# 84 93
# phase len 95
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m02.5kg
# 131 140
# phase len 151
# file_name 1.xlsx
# 109 119
# phase len 128
# file_name 2.xlsx
# 39 45
# phase len 58
# file_name 3.xlsx
# 105 113
# phase len 123
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m04.5kg
# 41 50
# phase len 64
# file_name 1.xlsx
# 119 128
# phase len 142
# file_name 2.xlsx
# 124 133
# phase len 147
# file_name 3.xlsx
# 129 134
# phase len 145
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m06.5kg
# 45 51
# phase len 66
# file_name 1.xlsx
# 118 129
# phase len 148
# file_name 2.xlsx
# 44 54
# phase len 74
# file_name 3.xlsx
# 149 160
# phase len 167
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m08.5kg
# 40 54
# phase len 75
# file_name 1.xlsx
# 104 118
# phase len 137
# file_name 2.xlsx
# 144 151
# phase len 173
# file_name 3.xlsx
# 151 166
# phase len 175
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m10.5kg
# 50 64
# phase len 86
# file_name 1.xlsx
# 110 123
# phase len 144
# file_name 2.xlsx
# 156 164
# phase len 186
# file_name 3.xlsx
# 171 186
# phase len 197
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m12.5kg
# 52 63
# phase len 84
# file_name 1.xlsx
# 116 127
# phase len 147
# file_name 2.xlsx
# 171 178
# phase len 204
# file_name 3.xlsx
# 204 216
# phase len 227
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m14.5kg
# 72 81
# phase len 84
# file_name 1.xlsx
# 123 134
# phase len 155
# file_name 2.xlsx
# 159 167
# phase len 191
# file_name 3.xlsx
# 168 179
# phase len 189
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m16.5kg
# 76 90
# phase len 93
# file_name 1.xlsx
# 129 142
# phase len 165
# file_name 2.xlsx
# 143 150
# phase len 177
# file_name 3.xlsx
# 192 207
# phase len 217
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m18.5kg
# 90 101
# phase len 105
# file_name 1.xlsx
# 126 140
# phase len 166
# file_name 2.xlsx
# 103 109
# phase len 134
# file_name 3.xlsx
# 176 193
# phase len 200
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m20.5kg
# 62 73
# phase len 77
# file_name 1.xlsx
# 139 150
# phase len 172
# file_name 2.xlsx
# 119 125
# phase len 156
# file_name 3.xlsx
# 177 191
# phase len 201
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m22.5kg
# 66 76
# phase len 80
# file_name 1.xlsx
# 138 146
# phase len 172
# file_name 2.xlsx
# 112 118
# phase len 145
# file_name 3.xlsx
# 186 201
# phase len 215
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m24.5kg
# 131 140
# phase len 145
# file_name 1.xlsx
# 134 142
# phase len 170
# file_name 2.xlsx
# 140 146
# phase len 174
# file_name 3.xlsx
# 184 199
# phase len 211
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m26.5kg
# 141 156
# phase len 159
# file_name 1.xlsx
# 107 116
# phase len 140
# file_name 2.xlsx
# 138 144
# phase len 172
# file_name 3.xlsx
# 184 200
# phase len 213
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m28.5kg
# 143 158
# phase len 160
# file_name 1.xlsx
# 123 131
# phase len 157
# file_name 2.xlsx
# 144 150
# phase len 178
# file_name 3.xlsx
# 101 115
# phase len 127
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m30.5kg
# 137 152
# phase len 154
# file_name 1.xlsx
# 128 137
# phase len 169
# file_name 2.xlsx
# 179 194
# phase len 212
# file_name 3.xlsx
# 99 113
# phase len 125
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m32.5kg
# 149 165
# phase len 167
# file_name 1.xlsx
# 133 143
# phase len 161
# file_name 2.xlsx
# 180 195
# phase len 214
# file_name 3.xlsx
# 57 69
# phase len 80
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m34.5kg
# 186 197
# phase len 199
# file_name 1.xlsx
# 148 151
# phase len 184
# file_name 2.xlsx
# 182 196
# phase len 210
# file_name 3.xlsx
# 64 74
# phase len 85
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr11m\11m35.0kg
# 180 193
# phase len 195
# file_name 1.xlsx
# 154 157
# phase len 188
# file_name 2.xlsx
# 189 204
# phase len 221
# file_name 3.xlsx
# 66 79
# phase len 92
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m00.5kg
# 46 47
# phase len 55
# file_name 1.xlsx
# 93 94
# phase len 103
# file_name 2.xlsx
# 36 39
# phase len 44
# file_name 3.xlsx
# 46 48
# phase len 50
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m02.5kg
# 141 148
# phase len 158
# file_name 1.xlsx
# 128 136
# phase len 146
# file_name 2.xlsx
# 136 143
# phase len 152
# file_name 3.xlsx
# 117 126
# phase len 130
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m04.5kg
# 50 58
# phase len 68
# file_name 1.xlsx
# 46 55
# phase len 71
# file_name 2.xlsx
# 40 48
# phase len 58
# file_name 3.xlsx
# 104 115
# phase len 120
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m06.5kg
# 49 56
# phase len 74
# file_name 1.xlsx
# 124 135
# phase len 152
# file_name 2.xlsx
# 117 123
# phase len 137
# file_name 3.xlsx
# 128 140
# phase len 144
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m08.5kg
# 54 64
# phase len 84
# file_name 1.xlsx
# 134 143
# phase len 161
# file_name 2.xlsx
# 125 133
# phase len 148
# file_name 3.xlsx
# 154 165
# phase len 170
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m10.5kg
# 51 62
# phase len 84
# file_name 1.xlsx
# 108 121
# phase len 140
# file_name 2.xlsx
# 62 68
# phase len 87
# file_name 3.xlsx
# 192 205
# phase len 211
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m12.5kg
# 56 67
# phase len 89
# file_name 1.xlsx
# 122 133
# phase len 153
# file_name 2.xlsx
# 152 158
# phase len 181
# file_name 3.xlsx
# 193 207
# phase len 215
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m14.5kg
# 56 66
# phase len 87
# file_name 1.xlsx
# 129 141
# phase len 162
# file_name 2.xlsx
# 89 95
# phase len 118
# file_name 3.xlsx
# 172 184
# phase len 190
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m16.5kg
# 70 81
# phase len 102
# file_name 1.xlsx
# 149 159
# phase len 179
# file_name 2.xlsx
# 87 93
# phase len 123
# file_name 3.xlsx
# 179 195
# phase len 201
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m18.5kg
# 64 72
# phase len 76
# file_name 1.xlsx
# 148 158
# phase len 177
# file_name 2.xlsx
# 60 65
# phase len 89
# file_name 3.xlsx
# 181 193
# phase len 202
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m20.5kg
# 97 107
# phase len 110
# file_name 1.xlsx
# 143 152
# phase len 171
# file_name 2.xlsx
# 238 244
# phase len 272
# file_name 3.xlsx
# 179 195
# phase len 200
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m22.5kg
# 66 74
# phase len 77
# file_name 1.xlsx
# 115 123
# phase len 147
# file_name 2.xlsx
# 238 249
# phase len 269
# file_name 3.xlsx
# 193 203
# phase len 212
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m24.5kg
# 62 71
# phase len 74
# file_name 1.xlsx
# 157 173
# phase len 187
# file_name 2.xlsx
# 244 254
# phase len 274
# file_name 3.xlsx
# 170 179
# phase len 187
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m26.5kg
# 67 75
# phase len 78
# file_name 1.xlsx
# 117 127
# phase len 149
# file_name 2.xlsx
# 247 259
# phase len 274
# file_name 3.xlsx
# 176 184
# phase len 192
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m28.5kg
# 70 79
# phase len 82
# file_name 1.xlsx
# 124 131
# phase len 159
# file_name 2.xlsx
# 203 211
# phase len 230
# file_name 3.xlsx
# 163 171
# phase len 182
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m30.5kg
# 89 96
# phase len 99
# file_name 1.xlsx
# 116 124
# phase len 150
# file_name 2.xlsx
# 192 193
# phase len 216
# file_name 3.xlsx
# 168 178
# phase len 185
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m32.5kg
# 170 177
# phase len 182
# file_name 1.xlsx
# 136 143
# phase len 169
# file_name 2.xlsx
# 179 190
# phase len 208
# file_name 3.xlsx
# 177 186
# phase len 193
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m34.5kg
# 181 190
# phase len 193
# file_name 1.xlsx
# 163 168
# phase len 201
# file_name 2.xlsx
# 172 185
# phase len 201
# file_name 3.xlsx
# 74 89
# phase len 99
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr13m\13m35.0kg
# 100 110
# phase len 113
# file_name 1.xlsx
# 159 165
# phase len 195
# file_name 2.xlsx
# 172 186
# phase len 203
# file_name 3.xlsx
# 74 88
# phase len 100
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m00.5kg
# 42 43
# phase len 53
# file_name 1.xlsx
# 100 101
# phase len 110
# file_name 2.xlsx
# 60 62
# phase len 73
# file_name 3.xlsx
# 68 70
# phase len 74
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m02.5kg
# 141 147
# phase len 157
# file_name 1.xlsx
# 142 147
# phase len 156
# file_name 2.xlsx
# 121 131
# phase len 139
# file_name 3.xlsx
# 142 150
# phase len 152
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m04.5kg
# 49 56
# phase len 68
# file_name 1.xlsx
# 65 73
# phase len 84
# file_name 2.xlsx
# 40 46
# phase len 57
# file_name 3.xlsx
# 150 157
# phase len 161
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m06.5kg
# 51 60
# phase len 77
# file_name 1.xlsx
# 136 143
# phase len 157
# file_name 2.xlsx
# 48 54
# phase len 69
# file_name 3.xlsx
# 88 95
# phase len 98
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m08.5kg
# 56 67
# phase len 83
# file_name 1.xlsx
# 130 141
# phase len 156
# file_name 2.xlsx
# 66 72
# phase len 88
# file_name 3.xlsx
# 122 133
# phase len 137
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m10.5kg
# 60 68
# phase len 85
# file_name 1.xlsx
# 150 156
# phase len 178
# file_name 2.xlsx
# 74 77
# phase len 95
# file_name 3.xlsx
# 123 135
# phase len 137
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m12.5kg
# 64 72
# phase len 92
# file_name 1.xlsx
# 144 150
# phase len 171
# file_name 2.xlsx
# 179 185
# phase len 202
# file_name 3.xlsx
# 124 136
# phase len 141
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m14.5kg
# 59 67
# phase len 90
# file_name 1.xlsx
# 151 167
# phase len 181
# file_name 2.xlsx
# 102 106
# phase len 123
# file_name 3.xlsx
# 131 145
# phase len 150
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m16.5kg
# 71 81
# phase len 106
# file_name 1.xlsx
# 153 168
# phase len 180
# file_name 2.xlsx
# 103 107
# phase len 126
# file_name 3.xlsx
# 235 245
# phase len 247
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m18.5kg
# 77 83
# phase len 105
# file_name 1.xlsx
# 156 174
# phase len 188
# file_name 2.xlsx
# 162 165
# phase len 189
# file_name 3.xlsx
# 245 255
# phase len 260
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m20.5kg
# 86 98
# phase len 101
# file_name 1.xlsx
# 173 192
# phase len 203
# file_name 2.xlsx
# 227 232
# phase len 255
# file_name 3.xlsx
# 225 235
# phase len 240
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m22.5kg
# 54 63
# phase len 66
# file_name 1.xlsx
# 125 134
# phase len 160
# file_name 2.xlsx
# 120 121
# phase len 146
# file_name 3.xlsx
# 218 230
# phase len 235
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m24.5kg
# 50 58
# phase len 61
# file_name 1.xlsx
# 124 131
# phase len 158
# file_name 2.xlsx
# 120 121
# phase len 148
# file_name 3.xlsx
# 238 250
# phase len 253
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m26.5kg
# 68 76
# phase len 79
# file_name 1.xlsx
# 126 131
# phase len 150
# file_name 2.xlsx
# 217 235
# phase len 247
# file_name 3.xlsx
# 256 265
# phase len 270
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m28.5kg
# 70 78
# phase len 81
# file_name 1.xlsx
# 134 141
# phase len 167
# file_name 2.xlsx
# 124 143
# phase len 152
# file_name 3.xlsx
# 243 256
# phase len 263
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m30.5kg
# 100 105
# phase len 108
# file_name 1.xlsx
# 145 150
# phase len 175
# file_name 2.xlsx
# 114 133
# phase len 150
# file_name 3.xlsx
# 264 278
# phase len 281
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m32.5kg
# 99 104
# phase len 108
# file_name 1.xlsx
# 162 167
# phase len 193
# file_name 2.xlsx
# 141 158
# phase len 168
# file_name 3.xlsx
# 264 277
# phase len 281
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m34.5kg
# 105 110
# phase len 131
# file_name 1.xlsx
# 161 166
# phase len 190
# file_name 2.xlsx
# 122 140
# phase len 153
# file_name 3.xlsx
# 268 284
# phase len 288
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr15m\15m35.0kg
# 102 107
# phase len 131
# file_name 1.xlsx
# 159 175
# phase len 189
# file_name 2.xlsx
# 122 141
# phase len 154
# file_name 3.xlsx
# 288 307
# phase len 311
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m00.5kg
# 43 50
# phase len 56
# file_name 1.xlsx
# 107 108
# phase len 117
# file_name 2.xlsx
# 75 78
# phase len 86
# file_name 3.xlsx
# 69 70
# phase len 74
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m02.5kg
# 131 136
# phase len 139
# file_name 1.xlsx
# 59 68
# phase len 77
# file_name 2.xlsx
# 79 86
# phase len 99
# file_name 3.xlsx
# 91 98
# phase len 100
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m04.5kg
# 54 64
# phase len 77
# file_name 1.xlsx
# 143 148
# phase len 162
# file_name 2.xlsx
# 40 45
# phase len 56
# file_name 3.xlsx
# 98 106
# phase len 108
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m06.5kg
# 53 60
# phase len 75
# file_name 1.xlsx
# 151 159
# phase len 173
# file_name 2.xlsx
# 56 61
# phase len 76
# file_name 3.xlsx
# 92 104
# phase len 107
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m08.5kg
# 54 63
# phase len 65
# file_name 1.xlsx
# 158 168
# phase len 184
# file_name 2.xlsx
# 73 78
# phase len 93
# file_name 3.xlsx
# 118 130
# phase len 134
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m10.5kg
# 67 75
# phase len 77
# file_name 1.xlsx
# 174 180
# phase len 202
# file_name 2.xlsx
# 90 95
# phase len 99
# file_name 3.xlsx
# 132 145
# phase len 149
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m12.5kg
# 81 89
# phase len 91
# file_name 1.xlsx
# 165 172
# phase len 193
# file_name 2.xlsx
# 105 109
# phase len 112
# file_name 3.xlsx
# 131 142
# phase len 146
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m14.5kg
# 87 93
# phase len 96
# file_name 1.xlsx
# 197 206
# phase len 227
# file_name 2.xlsx
# 113 118
# phase len 121
# file_name 3.xlsx
# 179 189
# phase len 195
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m16.5kg
# 83 91
# phase len 94
# file_name 1.xlsx
# 205 212
# phase len 233
# file_name 2.xlsx
# 161 162
# phase len 166
# file_name 3.xlsx
# 199 209
# phase len 212
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m18.5kg
# 100 109
# phase len 112
# file_name 1.xlsx
# 200 207
# phase len 231
# file_name 2.xlsx
# 214 216
# phase len 239
# file_name 3.xlsx
# 148 159
# phase len 162
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m20.5kg
# 105 113
# phase len 116
# file_name 1.xlsx
# 219 226
# phase len 252
# file_name 2.xlsx
# 168 180
# phase len 195
# file_name 3.xlsx
# 163 176
# phase len 181
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m22.5kg
# 114 121
# phase len 124
# file_name 1.xlsx
# 164 173
# phase len 200
# file_name 2.xlsx
# 180 194
# phase len 208
# file_name 3.xlsx
# 167 179
# phase len 181
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m24.5kg
# 70 78
# phase len 81
# file_name 1.xlsx
# 184 191
# phase len 217
# file_name 2.xlsx
# 236 253
# phase len 264
# file_name 3.xlsx
# 189 201
# phase len 203
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m26.5kg
# 71 80
# phase len 82
# file_name 1.xlsx
# 174 179
# phase len 209
# file_name 2.xlsx
# 223 237
# phase len 252
# file_name 3.xlsx
# 195 207
# phase len 216
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m28.5kg
# 87 93
# phase len 96
# file_name 1.xlsx
# 178 196
# phase len 217
# file_name 2.xlsx
# 241 255
# phase len 266
# file_name 3.xlsx
# 195 206
# phase len 213
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m30.5kg
# 97 104
# phase len 107
# file_name 1.xlsx
# 180 186
# phase len 218
# file_name 2.xlsx
# 166 185
# phase len 195
# file_name 3.xlsx
# 202 218
# phase len 224
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m32.5kg
# 93 98
# phase len 122
# file_name 1.xlsx
# 191 197
# phase len 231
# file_name 2.xlsx
# 174 190
# phase len 201
# file_name 3.xlsx
# 211 222
# phase len 228
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m34.5kg
# 95 100
# phase len 126
# file_name 1.xlsx
# 212 228
# phase len 250
# file_name 2.xlsx
# 202 217
# phase len 232
# file_name 3.xlsx
# 219 228
# phase len 233
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr17m\17m35.0kg
# 119 124
# phase len 150
# file_name 1.xlsx
# 211 226
# phase len 248
# file_name 2.xlsx
# 219 235
# phase len 248
# file_name 3.xlsx
# 232 243
# phase len 251
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m00.5kg
# 34 40
# phase len 42
# file_name 1.xlsx
# 76 77
# phase len 79
# file_name 2.xlsx
# 61 64
# phase len 66
# file_name 3.xlsx
# 58 61
# phase len 63
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m02.5kg
# 63 66
# phase len 68
# file_name 1.xlsx
# 124 130
# phase len 133
# file_name 2.xlsx
# 47 52
# phase len 55
# file_name 3.xlsx
# 41 44
# phase len 45
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m04.5kg
# 116 121
# phase len 124
# file_name 1.xlsx
# 100 106
# phase len 117
# file_name 2.xlsx
# 50 55
# phase len 59
# file_name 3.xlsx
# 58 63
# phase len 65
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m06.5kg
# 73 79
# phase len 88
# file_name 1.xlsx
# 105 111
# phase len 123
# file_name 2.xlsx
# 23 27
# phase len 29
# file_name 3.xlsx
# 82 85
# phase len 87
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m08.5kg
# 86 95
# phase len 100
# file_name 1.xlsx
# 98 103
# phase len 115
# file_name 2.xlsx
# 95 105
# phase len 108
# file_name 3.xlsx
# 59 65
# phase len 68
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m10.5kg
# 95 101
# phase len 111
# file_name 1.xlsx
# 113 118
# phase len 131
# file_name 2.xlsx
# 53 66
# phase len 71
# file_name 3.xlsx
# 68 73
# phase len 76
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m12.5kg
# 90 96
# phase len 107
# file_name 1.xlsx
# 118 124
# phase len 138
# file_name 2.xlsx
# 62 66
# phase len 69
# file_name 3.xlsx
# 98 102
# phase len 105
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m14.5kg
# 91 97
# phase len 109
# file_name 1.xlsx
# 129 137
# phase len 152
# file_name 2.xlsx
# 87 88
# phase len 91
# file_name 3.xlsx
# 107 113
# phase len 116
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m16.5kg
# 126 129
# phase len 142
# file_name 1.xlsx
# 140 145
# phase len 160
# file_name 2.xlsx
# 129 140
# phase len 143
# file_name 3.xlsx
# 132 138
# phase len 141
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m18.5kg
# 137 140
# phase len 153
# file_name 1.xlsx
# 153 158
# phase len 173
# file_name 2.xlsx
# 135 145
# phase len 151
# file_name 3.xlsx
# 116 122
# phase len 125
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m20.5kg
# 127 130
# phase len 146
# file_name 1.xlsx
# 182 191
# phase len 204
# file_name 2.xlsx
# 130 142
# phase len 150
# file_name 3.xlsx
# 116 122
# phase len 124
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m22.5kg
# 143 147
# phase len 162
# file_name 1.xlsx
# 177 185
# phase len 202
# file_name 2.xlsx
# 139 152
# phase len 157
# file_name 3.xlsx
# 130 136
# phase len 138
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m24.5kg
# 148 151
# phase len 168
# file_name 1.xlsx
# 190 204
# phase len 214
# file_name 2.xlsx
# 133 146
# phase len 149
# file_name 3.xlsx
# 133 142
# phase len 144
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m26.5kg
# 146 148
# phase len 162
# file_name 1.xlsx
# 187 199
# phase len 214
# file_name 2.xlsx
# 137 151
# phase len 157
# file_name 3.xlsx
# 144 151
# phase len 154
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m28.5kg
# 163 171
# phase len 183
# file_name 1.xlsx
# 186 203
# phase len 213
# file_name 2.xlsx
# 137 145
# phase len 153
# file_name 3.xlsx
# 155 161
# phase len 164
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m30.5kg
# 149 157
# phase len 169
# file_name 1.xlsx
# 192 209
# phase len 217
# file_name 2.xlsx
# 185 199
# phase len 204
# file_name 3.xlsx
# 154 161
# phase len 165
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m32.5kg
# 165 172
# phase len 186
# file_name 1.xlsx
# 181 196
# phase len 207
# file_name 2.xlsx
# 172 182
# phase len 192
# file_name 3.xlsx
# 165 170
# phase len 173
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m34.5kg
# 150 159
# phase len 173
# file_name 1.xlsx
# 185 204
# phase len 214
# file_name 2.xlsx
# 132 148
# phase len 154
# file_name 3.xlsx
# 179 185
# phase len 189
# file_name 4.xlsx
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr19m\19m35.0kg
# 160 169
# phase len 182
# file_name 1.xlsx
# 180 201
# phase len 212
# file_name 2.xlsx
# 139 150
# phase len 157
# file_name 3.xlsx
# 164 170
# phase len 172
# file_name 4.xlsx
# OUTPUT 2 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr21m
# OUTPUT 3 G:\Chamodi\LSDYNA3D\RP_TH_models\RP_section_datasets_reduced\RP_curves_fr21m\21m00.5kg
# 35 40
# phase len 42
# file_name 1.xlsx
# 41 46
# phase len 49
# file_name 2.xlsx
# 52 55
# phase len 62
# file_name 3.xlsx
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 44
#      40 AP = pressure[0]
#      42 reduced_time, reduced_pressure = reduce_points(time, pressure, file1)
# ---> 44 TT, TP, CT, CP, ET, EP = find_CTE(reduced_pressure, reduced_time, file1, EM, SD, A)
#      47 # Creating a new DataFrame to append
#      48 row_all = pd.DataFrame({"Mass": [EM], "Standoff distance": [SD], "Angle": [A],
#      49                         "Arrival time": [AT],"AP": [AP],
#      50                         "Change time": [CT], "CP": [CP],
#      51                         "Trough time": [TT], "TP": [TP],
#      52                         "End time": [ET], "EP": [EP],
#      53                         "Original":[len(pressure)], "Reduced": [len(reduced_pressure)]})
#
# Cell In[5], line 18, in find_CTE(reduced_pressure, reduced_time, file1, EM, SD, A)
#      14 ET = reduced_time[-1]
#      15 EP = reduced_pressure[-1]
# ---> 18 phase = get_phase_array(reduced_time, reduced_pressure, CT, CP, TT, TP)
#      20 print (zero_crossing_index_1, lowest_index2)
#      21 print('phase len', len(phase))
#
# Cell In[4], line 6, in get_phase_array(time, pressure, CT, CP, TT, TP)
#       4 phase = []
#       5 for t, p in zip(time, pressure):
# ----> 6     if round (t, 10) < round (CT, 10):
#       7         phase.append('positive')#{t} {change_time}')
#       8     elif round (CT, 10) <= round (t, 10) < round(TT, 10):
#
# TypeError: type numpy.ndarray doesn't define __round__ method

# %%
# Write dataframes in excel template
all_path = 'RP_far_field_all_reduced.xlsx'

df_all.to_excel(all_path, index=False)
