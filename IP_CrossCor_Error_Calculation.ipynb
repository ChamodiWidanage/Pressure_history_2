# %%
import pandas as pd
from keras.models import load_model
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import random
from scipy.integrate import quad
from scipy.interpolate import interp1d

ann_arr = load_model('IP_Arrival_time/Arrival_ANN_1')
ann_end = load_model('IP_End_time/End_ANN_2')
ann_chg = load_model('IP_Change_time/Change_ANN_3')

#Section1
ann1 = load_model('IP_Section_1_new/Section1_ANN_3')
sc1 = pickle.load(open('IP_Section_1_new/Section1_scaler_ANN_3.pkl', 'rb'))
#Section2
ann2 = load_model('IP_Section_2_new/Section2_new_ANN_5')
sc2 = pickle.load(open('IP_Section_2_new/Section2_new_scaler_ANN_5.pkl', 'rb'))
#Section3
ann3 = load_model('IP_Section_3_new/Section3_new_ANN_1')
sc3 = pickle.load(open('IP_Section_3_new/Section3_new_scaler_ANN_1.pkl', 'rb'))
#Section4
ann4 = load_model('IP_Section_4_new/Section4_new_ANN_1')
sc4 = pickle.load(open('IP_Section_4_new/Section4_new_scaler_ANN_1.pkl', 'rb'))
#Section5
ann5 = load_model('IP_Section_5_new/Section5_new_ANN_1')
sc5 = pickle.load(open('IP_Section_5_new/Section5_new_scaler_ANN_1.pkl', 'rb'))
#Section6
ann6 = load_model('IP_Section_6_new/Section6_new_ANN_1')
sc6 = pickle.load(open('IP_Section_6_new/Section6_new_scaler_ANN_1.pkl', 'rb'))
# Out:
# WARNING:tensorflow:From D:\Anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# WARNING:tensorflow:From D:\Anaconda3\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# WARNING:tensorflow:From D:\Anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:585: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# D:\Anaconda3\Lib\site-packages\sklearn\base.py:347: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Mapping logic based on Section
def get_scaler_and_model(section):
    sc = scalers.get(section)
    ann = models.get(section)

    if sc is None or ann is None:
        raise ValueError(f"Invalid Section: {section}. Valid sections are 1 to 6.")

    return sc, ann

def get_filename_range(section):
    max_boundary = max_filename.get(section)
    min_boundary = min_filename.get(section)
    
    if max_boundary is None or min_boundary is None:
        raise ValueError(f"Invalid Section: {section}. Valid sections are 1 to 6.")
    
    return max_boundary, min_boundary
    

# Perform trapezoidal rule integration
def integrate_with_TR(time, y):
    cumulative_integration = np.cumsum(np.gradient(time) * y)
    
    return cumulative_integration

# Function to perform integration
def perform_integration(file_path, Mass, Distance, file_name):
    # Load the Excel file
    df = pd.read_excel(file_path)
    # Filter the DataFrame to keep only rows with matching Mass and Distance
    df_filtered = df[(df['Mass'] == Mass) & (df['Standoff distance'] == Distance)]

    # If the filtered DataFrame is empty, raise an error or return a default value
    if df_filtered.empty:
        raise ValueError(f"No rows found matching the specified Mass {Mass}, Distance {Distance}, Filename {file_name} and Filepath {file_path}.")
    
    # Sort the filtered DataFrame by Time in ascending order
    df_sorted = df_filtered.sort_values(by='Time', ascending=True)
    
    # Extract time and pressure values
    time_num = df_sorted['Time'].values  # Assuming time is in seconds and converting to milliseconds
    y_num = df_sorted['Pressure'].values  # Pressure units adjustment (kPa)
    cumulative_integration = integrate_with_TR(time_num, y_num)
    
    # Find the maximum time value
    max_time = np.max(time_num)
    
    return max_time, cumulative_integration[-1]

def stable_state(start, end, interval):    
    t = np.arange(start, end + interval, interval)
    t = t.reshape(len(t),1)

    p = np.repeat(0, len(t)).reshape(len(t),1)
    
    values = np.concatenate ((t, p), axis = 1)
    return values

def p_fluctuation(d_set, sc, ann):
    d_set[:,0:3] = sc.transform(d_set[:,0:3])
    p_f = ann.predict(d_set)
    return p_f

# Define the function to generate time_ann and y_ann
def predict_ann(Distance, Mass, termination_time, sc, ann, interval=0.01):

    arr = np.array ([[Mass,Distance]])
    arrival_time = ann_arr.predict(arr)
    end_time = ann_end.predict(arr)
    change_time = ann_chg.predict(arr)
    #print ("1",arrival_time,end_time, change_time)

    if termination_time < end_time:
        end_time = termination_time
        
    else:
        start = end_time
        end = termination_time
        values3 = stable_state(start, end, interval)
    #print ("2",arrival_time,end_time, Distance, Mass, Angle)
    t2= np.arange(arrival_time, end_time + interval, interval)
    t2 = t2.reshape(len(t2),1)
    
    if t2[0] < change_time:
        ph2 = np.array([[0, 1]])
    else:
        ph2 = np.array([[1, 0]])
        
    positive = np.array([0, 1])
    negative= np.array([1, 0])
    
    for time in t2[1:]:
        if time < change_time:
            ph2=np.vstack((ph2,positive))
        else:
            ph2=np.vstack((ph2,negative))
            
    m2 = np.repeat(Mass, len(t2)).reshape(len(t2),1)
    d2 = np.repeat(Distance, len(t2)).reshape(len(t2),1)
    d_set = np.concatenate ((m2, d2, t2, ph2), axis = 1)
    
    #p2 = p_fluctuation(Standoff_distance, d_set)
    p2 = p_fluctuation(d_set, sc, ann)
    p2 = p2.reshape((-1, 1))
    values2 = np.concatenate ((t2, p2), axis = 1)
    
    if 'values3' in locals():
        ml_model = np.concatenate((values2, values3), axis=0)
    else:
        ml_model = values2
        
    time = ml_model[:,0]
    y = ml_model[:,1]
    max_time_ann = max(time)
    
    cumulative_integration = integrate_with_TR(time, y)
    
    return cumulative_integration[-1], max_time_ann

# %%
# Define the root directory and section
root_dir = Path("G:/Chamodi/LSDYNA_1D/Incident_pressure_time_history/Far_field_time_history_dataset")
Section = 2

#distance_mapping = {'5': 1.5, '7': 1.75, '9': 2, '11': 2.25, '13': 2.5, '15': 2.75, '17': 3}
scalers = {1: sc1, 2: sc2, 3: sc3, 4: sc4, 5: sc5, 6: sc6}
models = {1: ann1, 2: ann2, 3: ann3, 4: ann4, 5: ann5, 6: ann6}
max_filename = {1: 18, 2: 14, 3: 26, 4: 38, 5: 50, 6: 60}
min_filename = {1: 4, 2: 2, 3: 12, 4: 24, 5: 36, 6: 48}

# List to store file paths and corresponding metadata
file_data = []

sc, ann = get_scaler_and_model(Section)
max_boundary, min_boundary = get_filename_range(Section)

# Traverse through all directories and subdirectories
for file_path in root_dir.rglob('*.xlsx'):
    # Extract the parent directory name
    parent_dir = file_path.parent.name
    
    # Parse distance and mass from the directory name
    _, rest = parent_dir.split('_', 1)
    mass = int(rest) / 2
    file_name = file_path.stem[1:]
    #file_name = file_path.stem
    #print(file_name)
    
    if min_boundary < int(file_name) < max_boundary:
        distance = np.ceil(int(file_name)/2)
        #distance = distance_mapping.get(file_name, None)
        df = pd.read_excel(file_path)
    else:
        continue
        
    
    # Append the data
    file_data.append({
        'path': str(file_path),
        'distance': float(distance),
        'mass': float(mass),
        'file name': file_name,
        'sc': sc,
        'ann': ann
    })

# Convert the data to a DataFrame
sampled_files = pd.DataFrame(file_data)

# Apply integration to the sampled files and add a new column
sampled_files[['termination_time', 'num_integration']] = sampled_files.apply(lambda row: pd.Series(perform_integration(row['path'], row['mass'], row['distance'], row['file name'])), axis=1)
# Apply ANN-based model to sampled files
sampled_files[['ml_integration', 'termination_time_ann']] = sampled_files.apply(
    lambda row: pd.Series(integrate_ann(row['distance'], row['mass'], row['termination_time'], row['sc'], row['ann'])), 
    axis=1)

# Print the updated sampled files DataFrame
print(sampled_files)

# Optionally, save the updated DataFrame to a CSV for later use
sampled_files.to_excel('IP_TR_integration.xlsx', index=False)
# Out:
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 84ms/step
# 41/41 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 37/37 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 39/39 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 86/86 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 78/78 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 83/83 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 93/93 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 84/84 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 90/90 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 99/99 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 90/90 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 32ms/step
# 95/95 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 104/104 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 95/95 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 101/101 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 109/109 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 100/100 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 105/105 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 114/114 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 104/104 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 109/109 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 118/118 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 108/108 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 113/113 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 121/121 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 112/112 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 117/117 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 125/125 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 115/115 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 120/120 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 128/128 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 118/118 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 123/123 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 65/65 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 59/59 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 63/63 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 131/131 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 121/121 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 126/126 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 133/133 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 124/124 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 128/128 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 136/136 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 127/127 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 131/131 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 138/138 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 130/130 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 134/134 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 141/141 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 133/133 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 136/136 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 14ms/step
# 141/141 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 133/133 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 137/137 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 77/77 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 70/70 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 74/74 [==============================] - 0s 2ms/step
#                                                  path  distance  mass  \
# 0   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0   0.5
# 1   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0   0.5
# 2   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0   0.5
# 3   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0   6.5
# 4   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0   6.5
# 5   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0   6.5
# 6   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0   8.5
# 7   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0   8.5
# 8   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0   8.5
# 9   G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  10.5
# 10  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  10.5
# 11  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  10.5
# 12  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  12.5
# 13  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  12.5
# 14  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  12.5
# 15  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  14.5
# 16  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  14.5
# 17  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  14.5
# 18  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  16.5
# 19  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  16.5
# 20  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  16.5
# 21  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  18.5
# 22  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  18.5
# 23  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  18.5
# 24  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  20.5
# 25  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  20.5
# 26  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  20.5
# 27  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  22.5
# 28  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  22.5
# 29  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  22.5
# 30  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  24.5
# 31  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  24.5
# 32  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  24.5
# 33  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0   2.5
# 34  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0   2.5
# 35  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0   2.5
# 36  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  26.5
# 37  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  26.5
# 38  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  26.5
# 39  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  28.5
# 40  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  28.5
# 41  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  28.5
# 42  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  30.5
# 43  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  30.5
# 44  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  30.5
# 45  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  32.5
# 46  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  32.5
# 47  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  32.5
# 48  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  34.5
# 49  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  34.5
# 50  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  34.5
# 51  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0  35.0
# 52  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0  35.0
# 53  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0  35.0
# 54  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       7.0   4.5
# 55  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       3.0   4.5
# 56  G:\Chamodi\LSDYNA_1D\Incident_pressure_time_hi...       5.0   4.5
#
#    file name                sc  \
# 0         13  StandardScaler()
# 1          5  StandardScaler()
# 2          9  StandardScaler()
# 3         13  StandardScaler()
# 4          5  StandardScaler()
# 5          9  StandardScaler()
# 6         13  StandardScaler()
# 7          5  StandardScaler()
# 8          9  StandardScaler()
# 9         13  StandardScaler()
# 10         5  StandardScaler()
# 11         9  StandardScaler()
# 12        13  StandardScaler()
# 13         5  StandardScaler()
# 14         9  StandardScaler()
# 15        13  StandardScaler()
# 16         5  StandardScaler()
# 17         9  StandardScaler()
# 18        13  StandardScaler()
# 19         5  StandardScaler()
# 20         9  StandardScaler()
# 21        13  StandardScaler()
# 22         5  StandardScaler()
# 23         9  StandardScaler()
# 24        13  StandardScaler()
# 25         5  StandardScaler()
# 26         9  StandardScaler()
# 27        13  StandardScaler()
# 28         5  StandardScaler()
# 29         9  StandardScaler()
# 30        13  StandardScaler()
# 31         5  StandardScaler()
# 32         9  StandardScaler()
# 33        13  StandardScaler()
# 34         5  StandardScaler()
# 35         9  StandardScaler()
# 36        13  StandardScaler()
# 37         5  StandardScaler()
# 38         9  StandardScaler()
# 39        13  StandardScaler()
# 40         5  StandardScaler()
# 41         9  StandardScaler()
# 42        13  StandardScaler()
# 43         5  StandardScaler()
# 44         9  StandardScaler()
# 45        13  StandardScaler()
# 46         5  StandardScaler()
# 47         9  StandardScaler()
# 48        13  StandardScaler()
# 49         5  StandardScaler()
# 50         9  StandardScaler()
# 51        13  StandardScaler()
# 52         5  StandardScaler()
# 53         9  StandardScaler()
# 54        13  StandardScaler()
# 55         5  StandardScaler()
# 56         9  StandardScaler()
#
#                                                   ann  termination_time  \
# 0   <keras.src.engine.sequential.Sequential object...         28.499948
# 1   <keras.src.engine.sequential.Sequential object...         16.599819
# 2   <keras.src.engine.sequential.Sequential object...         22.529779
# 3   <keras.src.engine.sequential.Sequential object...         38.799975
# 4   <keras.src.engine.sequential.Sequential object...         27.459700
# 5   <keras.src.engine.sequential.Sequential object...         32.979786
# 6   <keras.src.engine.sequential.Sequential object...         40.489700
# 7   <keras.src.engine.sequential.Sequential object...         29.329866
# 8   <keras.src.engine.sequential.Sequential object...         34.709852
# 9   <keras.src.engine.sequential.Sequential object...         41.949909
# 10  <keras.src.engine.sequential.Sequential object...         30.979926
# 11  <keras.src.engine.sequential.Sequential object...         36.209770
# 12  <keras.src.engine.sequential.Sequential object...         43.239810
# 13  <keras.src.engine.sequential.Sequential object...         32.459762
# 14  <keras.src.engine.sequential.Sequential object...         37.529729
# 15  <keras.src.engine.sequential.Sequential object...         44.389788
# 16  <keras.src.engine.sequential.Sequential object...         33.799786
# 17  <keras.src.engine.sequential.Sequential object...         38.719691
# 18  <keras.src.engine.sequential.Sequential object...         45.469835
# 19  <keras.src.engine.sequential.Sequential object...         35.069734
# 20  <keras.src.engine.sequential.Sequential object...         39.829738
# 21  <keras.src.engine.sequential.Sequential object...         46.469864
# 22  <keras.src.engine.sequential.Sequential object...         36.259990
# 23  <keras.src.engine.sequential.Sequential object...         40.869974
# 24  <keras.src.engine.sequential.Sequential object...         47.379773
# 25  <keras.src.engine.sequential.Sequential object...         37.369978
# 26  <keras.src.engine.sequential.Sequential object...         41.819856
# 27  <keras.src.engine.sequential.Sequential object...         48.249777
# 28  <keras.src.engine.sequential.Sequential object...         38.419757
# 29  <keras.src.engine.sequential.Sequential object...         42.729914
# 30  <keras.src.engine.sequential.Sequential object...         49.069945
# 31  <keras.src.engine.sequential.Sequential object...         39.429724
# 32  <keras.src.engine.sequential.Sequential object...         43.579798
# 33  <keras.src.engine.sequential.Sequential object...         33.829998
# 34  <keras.src.engine.sequential.Sequential object...         22.150001
# 35  <keras.src.engine.sequential.Sequential object...         27.930001
# 36  <keras.src.engine.sequential.Sequential object...         49.829707
# 37  <keras.src.engine.sequential.Sequential object...         40.389758
# 38  <keras.src.engine.sequential.Sequential object...         44.389941
# 39  <keras.src.engine.sequential.Sequential object...         50.569966
# 40  <keras.src.engine.sequential.Sequential object...         41.319981
# 41  <keras.src.engine.sequential.Sequential object...         45.159951
# 42  <keras.src.engine.sequential.Sequential object...         51.279932
# 43  <keras.src.engine.sequential.Sequential object...         42.209771
# 44  <keras.src.engine.sequential.Sequential object...         45.919850
# 45  <keras.src.engine.sequential.Sequential object...         51.939752
# 46  <keras.src.engine.sequential.Sequential object...         43.029703
# 47  <keras.src.engine.sequential.Sequential object...         46.619982
# 48  <keras.src.engine.sequential.Sequential object...         52.609999
# 49  <keras.src.engine.sequential.Sequential object...         43.859731
# 50  <keras.src.engine.sequential.Sequential object...         47.329798
# 51  <keras.src.engine.sequential.Sequential object...         52.769978
# 52  <keras.src.engine.sequential.Sequential object...         44.079825
# 53  <keras.src.engine.sequential.Sequential object...         47.509950
# 54  <keras.src.engine.sequential.Sequential object...         36.690000
# 55  <keras.src.engine.sequential.Sequential object...         25.180001
# 56  <keras.src.engine.sequential.Sequential object...         30.830000
#
#     num_integration  ml_integration  termination_time_ann
# 0          1.609072       -2.687258             28.504202
# 1         -0.505278      -20.771367             16.604357
# 2          0.847173       -8.549029             22.534040
# 3         -1.164225        4.669098             38.807766
# 4        -27.114834      -55.517635             27.468878
# 5         -5.287962       -9.161978             32.984745
# 6         -2.790809       -3.962761             40.495148
# 7        -26.799919      -68.454491             29.336698
# 8         -8.333292      -14.443580             34.713692
# 9         -4.030743      -10.352073             41.956089
# 10       -35.611446      -70.255753             30.987039
# 11       -14.923621      -16.875415             36.214578
# 12        -5.973559      -12.924245             43.247751
# 13       -35.117475      -66.320731             32.464167
# 14       -14.920383      -16.512047             37.534223
# 15        -7.532949      -12.463018             44.393450
# 16       -36.000678      -60.719183             33.804379
# 17       -22.444017      -14.263742             38.722947
# 18        -5.921073      -10.338728             45.473087
# 19       -33.906399      -56.503508             35.072308
# 20       -26.269468      -11.530350             39.831532
# 21        -7.436952       -7.519194             46.471874
# 22       -31.290683      -54.069921             36.261511
# 23       -25.096350       -8.935779             40.878130
# 24       -13.048554       -4.834223             47.382729
# 25       -24.217762      -53.563319             37.375851
# 26       -29.429142       -7.848337             41.827774
# 27       -14.945704       -3.493388             48.253834
# 28       -18.641311      -54.249930             38.420360
# 29       -36.911335       -8.480979             42.733806
# 30       -16.379173       -3.949149             49.079171
# 31       -15.255684      -55.380361             39.439079
# 32       -34.696991      -10.655747             43.589512
# 33         1.065208        9.644146             33.830853
# 34        -5.656610      -14.871890             22.159655
# 35        -0.945795       -1.866076             27.936209
# 36       -18.703419       -6.020691             49.840552
# 37        -6.313888      -56.553723             40.397778
# 38       -42.981818      -13.783193             44.399188
# 39       -14.801659       -9.231122             50.579725
# 40        -3.755735      -57.724377             41.320770
# 41       -40.922532      -17.403627             45.168573
# 42       -17.159043      -13.021795             51.289770
# 43         3.248852      -59.088963             42.210899
# 44       -42.313653      -21.111101             45.924771
# 45       -24.066046      -16.946992             51.945656
# 46        14.186330      -60.982381             43.031967
# 47       -46.239367      -24.672673             46.625984
# 48       -20.318382      -20.771578             52.614098
# 49        27.999103      -63.670530             43.862785
# 50       -47.887642      -28.101682             47.330130
# 51       -21.865615      -21.698601             52.776375
# 52        23.287849      -64.556562             44.086599
# 53       -46.769247      -28.909377             47.511964
# 54         0.162258       10.882100             36.699661
# 55       -18.001882      -34.854617             25.189035
# 56        -4.360170       -4.262392             30.838758
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 58
#      55 print(sampled_files)
#      57 # Optionally, save the updated DataFrame to a CSV for later use
# ---> 58 sampled_files.to_excel('IP_TR_integration.xlsx', index=False)
#
# File D:\Anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\Anaconda3\Lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\formats\excel.py:944, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     940     need_save = False
#     941 else:
#     942     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944     writer = ExcelWriter(  # type: ignore[abstract]
#     945         writer, engine=engine, storage_options=storage_options
#     946     )
#     947     need_save = True
#     949 try:
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1313, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1309 self._handles = IOHandles(
#    1310     cast(IO[bytes], path), compression={"compression": None}
#    1311 )
#    1312 if not isinstance(path, ExcelWriter):
# -> 1313     self._handles = get_handle(
#    1314         path, mode, storage_options=storage_options, is_text=False
#    1315     )
#    1316 self._cur_sheet = None
#    1318 if date_format is None:
#
# File D:\Anaconda3\Lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'IP_TR_integration.xlsx'

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

file_path = 'IP_TR_integration.xlsx'
data = pd.read_excel(file_path, sheet_name= 'Sheet2')

#data = data.sample(frac=0.3, random_state=40)

# Extract the numerical and ML model integration values
numerical_values = data['num_integration']
ml_model_values = data['ml_integration']

# Calculate MAE
mae = mean_absolute_error(numerical_values, ml_model_values)

# Calculate RMSE
rmse = mean_squared_error(numerical_values, ml_model_values, squared=False)

# Calculate R2
r2 = r2_score(numerical_values, ml_model_values)

# Print the results
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Coefficient of Determination (R^2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 4.8121
# Root Mean Squared Error (RMSE): 5.7989
# Coefficient of Determination (R^2): 0.4546
