# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pandas as pd
import math
import openpyxl

# %% [markdown]
# # Create peak pressure file - Attempt 1 (without peak index)

# %% [markdown]
# ## Access input folders

# %%
#Access input folder
input_dir1 = Path ("Pressure_curves_ascii")
print ("1",input_dir1)

#Access folders inside input folder
input_dir2 =  [folder for folder in input_dir1.iterdir() if folder.is_dir()]
print ("2",input_dir2)
# Out:
# 1 Pressure_curves_ascii
# 2 [WindowsPath('Pressure_curves_ascii/L13_1'), WindowsPath('Pressure_curves_ascii/L13_11'), WindowsPath('Pressure_curves_ascii/L13_13'), WindowsPath('Pressure_curves_ascii/L13_15'), WindowsPath('Pressure_curves_ascii/L13_17'), WindowsPath('Pressure_curves_ascii/L13_19'), WindowsPath('Pressure_curves_ascii/L13_21'), WindowsPath('Pressure_curves_ascii/L13_23'), WindowsPath('Pressure_curves_ascii/L13_25'), WindowsPath('Pressure_curves_ascii/L13_27'), WindowsPath('Pressure_curves_ascii/L13_29'), WindowsPath('Pressure_curves_ascii/L13_3'), WindowsPath('Pressure_curves_ascii/L13_31'), WindowsPath('Pressure_curves_ascii/L13_33'), WindowsPath('Pressure_curves_ascii/L13_35'), WindowsPath('Pressure_curves_ascii/L13_37'), WindowsPath('Pressure_curves_ascii/L13_39'), WindowsPath('Pressure_curves_ascii/L13_41'), WindowsPath('Pressure_curves_ascii/L13_43'), WindowsPath('Pressure_curves_ascii/L13_45'), WindowsPath('Pressure_curves_ascii/L13_47'), WindowsPath('Pressure_curves_ascii/L13_49'), WindowsPath('Pressure_curves_ascii/L13_5'), WindowsPath('Pressure_curves_ascii/L13_51'), WindowsPath('Pressure_curves_ascii/L13_53'), WindowsPath('Pressure_curves_ascii/L13_55'), WindowsPath('Pressure_curves_ascii/L13_57'), WindowsPath('Pressure_curves_ascii/L13_59'), WindowsPath('Pressure_curves_ascii/L13_61'), WindowsPath('Pressure_curves_ascii/L13_63'), WindowsPath('Pressure_curves_ascii/L13_65'), WindowsPath('Pressure_curves_ascii/L13_67'), WindowsPath('Pressure_curves_ascii/L13_69'), WindowsPath('Pressure_curves_ascii/L13_7'), WindowsPath('Pressure_curves_ascii/L13_70'), WindowsPath('Pressure_curves_ascii/L13_9')]

# %% [markdown]
# ## Create output files 1

# %%
# %%timeit -r1 -n1
# define current work directory
current_dir = Path.cwd()

# access the template to be used to generate files
excel_template = current_dir/ "Template.xlsx"

# Access each folder inside input folder
for folder in input_dir2:
    print ("folder", folder)
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
    
    # Make a set of file names
    keys = set (file.stem for file in files)
    
    # Use xlwings library to create excel files
    with xw.App (visible = False) as app:
        
        # for loop for keys
        for key in keys:
            
            # Open template excel file
            wb = app.books.open(excel_template)
            
            # for loop for files
            for file in files:
                if file.stem == key:
                    print ("file.stem = ", file.stem)
                    print ("key = ", key)
                    df = pd.read_csv(file, delimiter="\s+", skiprows = 8, skipfooter = 1, header = None, names = ["time", "pressure"])
                    wb.sheets[0].range("A1").options(index=False).value = df
            output_dir = current_dir/ "Pressure_curves_excel"
            output_dir.mkdir(exist_ok = True)
            output_dir1 = output_dir/ folder.stem
            output_dir1.mkdir(exist_ok = True)
            wb.save(output_dir1/f"{key}.xlsx")
        #print ("file",folder.stem, file.stem)
        #current_dir = Path.cwd()
        #excel_template = current_dir/ "Template.xlsx"
# Out:
# folder Input\L803
# file.stem =  T8
# key =  T8
# file.stem =  T14
# key =  T14
# file.stem =  T37
# key =  T37
# file.stem =  T38
# key =  T38
# file.stem =  T36
# key =  T36
# file.stem =  T9
# key =  T9
# file.stem =  T30
# key =  T30
# file.stem =  T5
# key =  T5
# file.stem =  T20
# key =  T20
# file.stem =  T12
# key =  T12
# file.stem =  T21
# key =  T21
# file.stem =  T3
# key =  T3
# file.stem =  T11
# key =  T11
# file.stem =  T18
# key =  T18
# file.stem =  T15
# key =  T15
# file.stem =  T4
# key =  T4
# file.stem =  T40
# key =  T40
# file.stem =  T22
# key =  T22
# file.stem =  T24
# key =  T24
# file.stem =  T1
# key =  T1
# file.stem =  T29
# key =  T29
# file.stem =  T23
# key =  T23
# file.stem =  T28
# key =  T28
# file.stem =  T13
# key =  T13
# file.stem =  T7
# key =  T7
# file.stem =  T17
# key =  T17
# file.stem =  T34
# key =  T34
# file.stem =  T39
# key =  T39
# file.stem =  T27
# key =  T27
# file.stem =  T35
# key =  T35
# file.stem =  T33
# key =  T33
# file.stem =  T19
# key =  T19
# file.stem =  T10
# key =  T10
# file.stem =  T2
# key =  T2
# file.stem =  T26
# key =  T26
# file.stem =  T25
# key =  T25
# file.stem =  T31
# key =  T31
# file.stem =  T32
# key =  T32
# file.stem =  T16
# key =  T16
# file.stem =  T6
# key =  T6
# folder Input\L804
# file.stem =  T8
# key =  T8
# file.stem =  T14
# key =  T14
# file.stem =  T37
# key =  T37
# file.stem =  T38
# key =  T38
# file.stem =  T36
# key =  T36
# file.stem =  T9
# key =  T9
# file.stem =  T30
# key =  T30
# file.stem =  T5
# key =  T5
# file.stem =  T20
# key =  T20
# file.stem =  T12
# key =  T12
# file.stem =  T21
# key =  T21
# file.stem =  T3
# key =  T3
# file.stem =  T11
# key =  T11
# file.stem =  T18
# key =  T18
# file.stem =  T15
# key =  T15
# file.stem =  T4
# key =  T4
# file.stem =  T40
# key =  T40
# file.stem =  T22
# key =  T22
# file.stem =  T24
# key =  T24
# file.stem =  T1
# key =  T1
# file.stem =  T29
# key =  T29
# file.stem =  T23
# key =  T23
# file.stem =  T28
# key =  T28
# file.stem =  T13
# key =  T13
# file.stem =  T7
# key =  T7
# file.stem =  T17
# key =  T17
# file.stem =  T34
# key =  T34
# file.stem =  T39
# key =  T39
# file.stem =  T27
# key =  T27
# file.stem =  T35
# key =  T35
# file.stem =  T33
# key =  T33
# file.stem =  T19
# key =  T19
# file.stem =  T10
# key =  T10
# file.stem =  T2
# key =  T2
# file.stem =  T26
# key =  T26
# file.stem =  T25
# key =  T25
# file.stem =  T31
# key =  T31
# file.stem =  T32
# key =  T32
# file.stem =  T16
# key =  T16
# file.stem =  T6
# key =  T6
# folder Input\L806
# file.stem =  T8
# key =  T8
# file.stem =  T14
# key =  T14
# file.stem =  T38
# key =  T38
# file.stem =  T36
# key =  T36
# file.stem =  T30
# key =  T30
# file.stem =  T20
# key =  T20
# file.stem =  T12
# key =  T12
# file.stem =  T18
# key =  T18
# file.stem =  T4
# key =  T4
# file.stem =  T40
# key =  T40
# file.stem =  T22
# key =  T22
# file.stem =  T24
# key =  T24
# file.stem =  T1
# key =  T1
# file.stem =  T28
# key =  T28
# file.stem =  T34
# key =  T34
# file.stem =  T26
# key =  T26
# file.stem =  T10
# key =  T10
# file.stem =  T2
# key =  T2
# file.stem =  T32
# key =  T32
# file.stem =  T16
# key =  T16
# file.stem =  T6
# key =  T6

# %% [markdown]
# ## Create output files 2

# %%
df = pd.DataFrame(columns = ['Charge_mass', 'Standoff_distance', 'Peak_Pressure', 'Peak_time'])
print (df)

# Access each folder inside input folder
for folder in input_dir2:
    print ("folder", folder)
    charge_mass = int(folder.stem[4:])/2
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
        
    # Access each file 
    for file in files:
        print ("file", file)
        stand_dis = math.ceil(int(file.stem[1:])/2)
            
        # Create a dataframe out of data files and use delimiters
        df1 = pd.read_csv(file,
                          delimiter="\s+",
                          skiprows = 7,
                          nrows= 1,
                          engine = 'python',
                          header = None)
            
        # append rows to an empty DataFrame
        new_row = {'Charge_mass' : [charge_mass], 'Standoff_distance' : [stand_dis], 'Peak_Pressure' : [df1.iloc[0,2]], 'Peak_time' : [df1.iloc[0,5]]}
        new_row_data = pd.DataFrame(new_row)
        df = pd.concat([df, new_row_data], ignore_index = True)
print (df)
# Out:
# Empty DataFrame
# Columns: [Charge_mass, Standoff_distance, Peak_Pressure, Peak_time]
# Index: []
# folder Pressure_curves_ascii\L13_1
# file Pressure_curves_ascii\L13_1\P1
# file Pressure_curves_ascii\L13_1\P13
# file Pressure_curves_ascii\L13_1\P17
# file Pressure_curves_ascii\L13_1\P21
# file Pressure_curves_ascii\L13_1\P25
# file Pressure_curves_ascii\L13_1\P29
# file Pressure_curves_ascii\L13_1\P33
# file Pressure_curves_ascii\L13_1\P37
# file Pressure_curves_ascii\L13_1\P41
# file Pressure_curves_ascii\L13_1\P45
# file Pressure_curves_ascii\L13_1\P49
# file Pressure_curves_ascii\L13_1\P5
# file Pressure_curves_ascii\L13_1\P53
# file Pressure_curves_ascii\L13_1\P57
# file Pressure_curves_ascii\L13_1\P59
# file Pressure_curves_ascii\L13_1\P9
# folder Pressure_curves_ascii\L13_11
# file Pressure_curves_ascii\L13_11\P1
# file Pressure_curves_ascii\L13_11\P13
# file Pressure_curves_ascii\L13_11\P17
# file Pressure_curves_ascii\L13_11\P21
# file Pressure_curves_ascii\L13_11\P25
# file Pressure_curves_ascii\L13_11\P29
# file Pressure_curves_ascii\L13_11\P33
# file Pressure_curves_ascii\L13_11\P37
# file Pressure_curves_ascii\L13_11\P41
# file Pressure_curves_ascii\L13_11\P45
# file Pressure_curves_ascii\L13_11\P49
# file Pressure_curves_ascii\L13_11\P5
# file Pressure_curves_ascii\L13_11\P53
# file Pressure_curves_ascii\L13_11\P57
# file Pressure_curves_ascii\L13_11\P59
# file Pressure_curves_ascii\L13_11\P9
# folder Pressure_curves_ascii\L13_13
# file Pressure_curves_ascii\L13_13\P1
# file Pressure_curves_ascii\L13_13\P13
# file Pressure_curves_ascii\L13_13\P17
# file Pressure_curves_ascii\L13_13\P21
# file Pressure_curves_ascii\L13_13\P25
# file Pressure_curves_ascii\L13_13\P29
# file Pressure_curves_ascii\L13_13\P33
# file Pressure_curves_ascii\L13_13\P37
# file Pressure_curves_ascii\L13_13\P41
# file Pressure_curves_ascii\L13_13\P45
# file Pressure_curves_ascii\L13_13\P49
# file Pressure_curves_ascii\L13_13\P5
# file Pressure_curves_ascii\L13_13\P53
# file Pressure_curves_ascii\L13_13\P57
# file Pressure_curves_ascii\L13_13\P59
# file Pressure_curves_ascii\L13_13\P9
# folder Pressure_curves_ascii\L13_15
# file Pressure_curves_ascii\L13_15\P1
# file Pressure_curves_ascii\L13_15\P13
# file Pressure_curves_ascii\L13_15\P17
# file Pressure_curves_ascii\L13_15\P21
# file Pressure_curves_ascii\L13_15\P25
# file Pressure_curves_ascii\L13_15\P29
# file Pressure_curves_ascii\L13_15\P33
# file Pressure_curves_ascii\L13_15\P37
# file Pressure_curves_ascii\L13_15\P41
# file Pressure_curves_ascii\L13_15\P45
# file Pressure_curves_ascii\L13_15\P49
# file Pressure_curves_ascii\L13_15\P5
# file Pressure_curves_ascii\L13_15\P53
# file Pressure_curves_ascii\L13_15\P57
# file Pressure_curves_ascii\L13_15\P59
# file Pressure_curves_ascii\L13_15\P9
# folder Pressure_curves_ascii\L13_17
# file Pressure_curves_ascii\L13_17\P1
# file Pressure_curves_ascii\L13_17\P13
# file Pressure_curves_ascii\L13_17\P17
# file Pressure_curves_ascii\L13_17\P21
# file Pressure_curves_ascii\L13_17\P25
# file Pressure_curves_ascii\L13_17\P29
# file Pressure_curves_ascii\L13_17\P33
# file Pressure_curves_ascii\L13_17\P37
# file Pressure_curves_ascii\L13_17\P41
# file Pressure_curves_ascii\L13_17\P45
# file Pressure_curves_ascii\L13_17\P49
# file Pressure_curves_ascii\L13_17\P5
# file Pressure_curves_ascii\L13_17\P53
# file Pressure_curves_ascii\L13_17\P57
# file Pressure_curves_ascii\L13_17\P59
# file Pressure_curves_ascii\L13_17\P9
# folder Pressure_curves_ascii\L13_19
# file Pressure_curves_ascii\L13_19\P1
# file Pressure_curves_ascii\L13_19\P13
# file Pressure_curves_ascii\L13_19\P17
# file Pressure_curves_ascii\L13_19\P21
# file Pressure_curves_ascii\L13_19\P25
# file Pressure_curves_ascii\L13_19\P29
# file Pressure_curves_ascii\L13_19\P33
# file Pressure_curves_ascii\L13_19\P37
# file Pressure_curves_ascii\L13_19\P41
# file Pressure_curves_ascii\L13_19\P45
# file Pressure_curves_ascii\L13_19\P49
# file Pressure_curves_ascii\L13_19\P5
# file Pressure_curves_ascii\L13_19\P53
# file Pressure_curves_ascii\L13_19\P57
# file Pressure_curves_ascii\L13_19\P59
# file Pressure_curves_ascii\L13_19\P9
# folder Pressure_curves_ascii\L13_21
# file Pressure_curves_ascii\L13_21\P1
# file Pressure_curves_ascii\L13_21\P13
# file Pressure_curves_ascii\L13_21\P17
# file Pressure_curves_ascii\L13_21\P21
# file Pressure_curves_ascii\L13_21\P25
# file Pressure_curves_ascii\L13_21\P29
# file Pressure_curves_ascii\L13_21\P33
# file Pressure_curves_ascii\L13_21\P37
# file Pressure_curves_ascii\L13_21\P41
# file Pressure_curves_ascii\L13_21\P45
# file Pressure_curves_ascii\L13_21\P49
# file Pressure_curves_ascii\L13_21\P5
# file Pressure_curves_ascii\L13_21\P53
# file Pressure_curves_ascii\L13_21\P57
# file Pressure_curves_ascii\L13_21\P59
# file Pressure_curves_ascii\L13_21\P9
# folder Pressure_curves_ascii\L13_23
# file Pressure_curves_ascii\L13_23\P1
# file Pressure_curves_ascii\L13_23\P13
# file Pressure_curves_ascii\L13_23\P17
# file Pressure_curves_ascii\L13_23\P21
# file Pressure_curves_ascii\L13_23\P25
# file Pressure_curves_ascii\L13_23\P29
# file Pressure_curves_ascii\L13_23\P33
# file Pressure_curves_ascii\L13_23\P37
# file Pressure_curves_ascii\L13_23\P41
# file Pressure_curves_ascii\L13_23\P45
# file Pressure_curves_ascii\L13_23\P49
# file Pressure_curves_ascii\L13_23\P5
# file Pressure_curves_ascii\L13_23\P53
# file Pressure_curves_ascii\L13_23\P57
# file Pressure_curves_ascii\L13_23\P59
# file Pressure_curves_ascii\L13_23\P9
# folder Pressure_curves_ascii\L13_25
# file Pressure_curves_ascii\L13_25\P1
# file Pressure_curves_ascii\L13_25\P13
# file Pressure_curves_ascii\L13_25\P17
# file Pressure_curves_ascii\L13_25\P21
# file Pressure_curves_ascii\L13_25\P25
# file Pressure_curves_ascii\L13_25\P29
# file Pressure_curves_ascii\L13_25\P33
# file Pressure_curves_ascii\L13_25\P37
# file Pressure_curves_ascii\L13_25\P41
# file Pressure_curves_ascii\L13_25\P45
# file Pressure_curves_ascii\L13_25\P49
# file Pressure_curves_ascii\L13_25\P5
# file Pressure_curves_ascii\L13_25\P53
# file Pressure_curves_ascii\L13_25\P57
# file Pressure_curves_ascii\L13_25\P59
# file Pressure_curves_ascii\L13_25\P9
# folder Pressure_curves_ascii\L13_27
# file Pressure_curves_ascii\L13_27\P1
# file Pressure_curves_ascii\L13_27\P13
# file Pressure_curves_ascii\L13_27\P17
# file Pressure_curves_ascii\L13_27\P21
# file Pressure_curves_ascii\L13_27\P25
# file Pressure_curves_ascii\L13_27\P29
# file Pressure_curves_ascii\L13_27\P33
# file Pressure_curves_ascii\L13_27\P37
# file Pressure_curves_ascii\L13_27\P41
# file Pressure_curves_ascii\L13_27\P45
# file Pressure_curves_ascii\L13_27\P49
# file Pressure_curves_ascii\L13_27\P5
# file Pressure_curves_ascii\L13_27\P53
# file Pressure_curves_ascii\L13_27\P57
# file Pressure_curves_ascii\L13_27\P59
# file Pressure_curves_ascii\L13_27\P9
# folder Pressure_curves_ascii\L13_29
# file Pressure_curves_ascii\L13_29\P1
# file Pressure_curves_ascii\L13_29\P13
# file Pressure_curves_ascii\L13_29\P17
# file Pressure_curves_ascii\L13_29\P21
# file Pressure_curves_ascii\L13_29\P25
# file Pressure_curves_ascii\L13_29\P29
# file Pressure_curves_ascii\L13_29\P33
# file Pressure_curves_ascii\L13_29\P37
# file Pressure_curves_ascii\L13_29\P41
# file Pressure_curves_ascii\L13_29\P45
# file Pressure_curves_ascii\L13_29\P49
# file Pressure_curves_ascii\L13_29\P5
# file Pressure_curves_ascii\L13_29\P53
# file Pressure_curves_ascii\L13_29\P57
# file Pressure_curves_ascii\L13_29\P59
# file Pressure_curves_ascii\L13_29\P9
# folder Pressure_curves_ascii\L13_3
# file Pressure_curves_ascii\L13_3\P1
# file Pressure_curves_ascii\L13_3\P13
# file Pressure_curves_ascii\L13_3\P17
# file Pressure_curves_ascii\L13_3\P21
# file Pressure_curves_ascii\L13_3\P25
# file Pressure_curves_ascii\L13_3\P29
# file Pressure_curves_ascii\L13_3\P33
# file Pressure_curves_ascii\L13_3\P37
# file Pressure_curves_ascii\L13_3\P41
# file Pressure_curves_ascii\L13_3\P45
# file Pressure_curves_ascii\L13_3\P49
# file Pressure_curves_ascii\L13_3\P5
# file Pressure_curves_ascii\L13_3\P53
# file Pressure_curves_ascii\L13_3\P57
# file Pressure_curves_ascii\L13_3\P59
# file Pressure_curves_ascii\L13_3\P9
# folder Pressure_curves_ascii\L13_31
# file Pressure_curves_ascii\L13_31\P1
# file Pressure_curves_ascii\L13_31\P13
# file Pressure_curves_ascii\L13_31\P17
# file Pressure_curves_ascii\L13_31\P21
# file Pressure_curves_ascii\L13_31\P25
# file Pressure_curves_ascii\L13_31\P29
# file Pressure_curves_ascii\L13_31\P33
# file Pressure_curves_ascii\L13_31\P37
# file Pressure_curves_ascii\L13_31\P41
# file Pressure_curves_ascii\L13_31\P45
# file Pressure_curves_ascii\L13_31\P49
# file Pressure_curves_ascii\L13_31\P5
# file Pressure_curves_ascii\L13_31\P53
# file Pressure_curves_ascii\L13_31\P57
# file Pressure_curves_ascii\L13_31\P59
# file Pressure_curves_ascii\L13_31\P9
# folder Pressure_curves_ascii\L13_33
# file Pressure_curves_ascii\L13_33\P1
# file Pressure_curves_ascii\L13_33\P13
# file Pressure_curves_ascii\L13_33\P17
# file Pressure_curves_ascii\L13_33\P21
# file Pressure_curves_ascii\L13_33\P25
# file Pressure_curves_ascii\L13_33\P29
# file Pressure_curves_ascii\L13_33\P33
# file Pressure_curves_ascii\L13_33\P37
# file Pressure_curves_ascii\L13_33\P41
# file Pressure_curves_ascii\L13_33\P45
# file Pressure_curves_ascii\L13_33\P49
# file Pressure_curves_ascii\L13_33\P5
# file Pressure_curves_ascii\L13_33\P53
# file Pressure_curves_ascii\L13_33\P57
# file Pressure_curves_ascii\L13_33\P59
# file Pressure_curves_ascii\L13_33\P9
# folder Pressure_curves_ascii\L13_35
# file Pressure_curves_ascii\L13_35\P1
# file Pressure_curves_ascii\L13_35\P13
# file Pressure_curves_ascii\L13_35\P17
# file Pressure_curves_ascii\L13_35\P21
# file Pressure_curves_ascii\L13_35\P25
# file Pressure_curves_ascii\L13_35\P29
# file Pressure_curves_ascii\L13_35\P33
# file Pressure_curves_ascii\L13_35\P37
# file Pressure_curves_ascii\L13_35\P41
# file Pressure_curves_ascii\L13_35\P45
# file Pressure_curves_ascii\L13_35\P49
# file Pressure_curves_ascii\L13_35\P5
# file Pressure_curves_ascii\L13_35\P53
# file Pressure_curves_ascii\L13_35\P57
# file Pressure_curves_ascii\L13_35\P59
# file Pressure_curves_ascii\L13_35\P9
# folder Pressure_curves_ascii\L13_37
# file Pressure_curves_ascii\L13_37\P1
# file Pressure_curves_ascii\L13_37\P13
# file Pressure_curves_ascii\L13_37\P17
# file Pressure_curves_ascii\L13_37\P21
# file Pressure_curves_ascii\L13_37\P25
# file Pressure_curves_ascii\L13_37\P29
# file Pressure_curves_ascii\L13_37\P33
# file Pressure_curves_ascii\L13_37\P37
# file Pressure_curves_ascii\L13_37\P41
# file Pressure_curves_ascii\L13_37\P45
# file Pressure_curves_ascii\L13_37\P49
# file Pressure_curves_ascii\L13_37\P5
# file Pressure_curves_ascii\L13_37\P53
# file Pressure_curves_ascii\L13_37\P57
# file Pressure_curves_ascii\L13_37\P59
# file Pressure_curves_ascii\L13_37\P9
# folder Pressure_curves_ascii\L13_39
# file Pressure_curves_ascii\L13_39\P1
# file Pressure_curves_ascii\L13_39\P13
# file Pressure_curves_ascii\L13_39\P17
# file Pressure_curves_ascii\L13_39\P21
# file Pressure_curves_ascii\L13_39\P25
# file Pressure_curves_ascii\L13_39\P29
# file Pressure_curves_ascii\L13_39\P33
# file Pressure_curves_ascii\L13_39\P37
# file Pressure_curves_ascii\L13_39\P41
# file Pressure_curves_ascii\L13_39\P45
# file Pressure_curves_ascii\L13_39\P49
# file Pressure_curves_ascii\L13_39\P5
# file Pressure_curves_ascii\L13_39\P53
# file Pressure_curves_ascii\L13_39\P57
# file Pressure_curves_ascii\L13_39\P59
# file Pressure_curves_ascii\L13_39\P9
# folder Pressure_curves_ascii\L13_41
# file Pressure_curves_ascii\L13_41\P1
# file Pressure_curves_ascii\L13_41\P13
# file Pressure_curves_ascii\L13_41\P17
# file Pressure_curves_ascii\L13_41\P21
# file Pressure_curves_ascii\L13_41\P25
# file Pressure_curves_ascii\L13_41\P29
# file Pressure_curves_ascii\L13_41\P33
# file Pressure_curves_ascii\L13_41\P37
# file Pressure_curves_ascii\L13_41\P41
# file Pressure_curves_ascii\L13_41\P45
# file Pressure_curves_ascii\L13_41\P49
# file Pressure_curves_ascii\L13_41\P5
# file Pressure_curves_ascii\L13_41\P53
# file Pressure_curves_ascii\L13_41\P57
# file Pressure_curves_ascii\L13_41\P59
# file Pressure_curves_ascii\L13_41\P9
# folder Pressure_curves_ascii\L13_43
# file Pressure_curves_ascii\L13_43\P1
# file Pressure_curves_ascii\L13_43\P13
# file Pressure_curves_ascii\L13_43\P17
# file Pressure_curves_ascii\L13_43\P21
# file Pressure_curves_ascii\L13_43\P25
# file Pressure_curves_ascii\L13_43\P29
# file Pressure_curves_ascii\L13_43\P33
# file Pressure_curves_ascii\L13_43\P37
# file Pressure_curves_ascii\L13_43\P41
# file Pressure_curves_ascii\L13_43\P45
# file Pressure_curves_ascii\L13_43\P49
# file Pressure_curves_ascii\L13_43\P5
# file Pressure_curves_ascii\L13_43\P53
# file Pressure_curves_ascii\L13_43\P57
# file Pressure_curves_ascii\L13_43\P59
# file Pressure_curves_ascii\L13_43\P9
# folder Pressure_curves_ascii\L13_45
# file Pressure_curves_ascii\L13_45\P1
# file Pressure_curves_ascii\L13_45\P13
# file Pressure_curves_ascii\L13_45\P17
# file Pressure_curves_ascii\L13_45\P21
# file Pressure_curves_ascii\L13_45\P25
# file Pressure_curves_ascii\L13_45\P29
# file Pressure_curves_ascii\L13_45\P33
# file Pressure_curves_ascii\L13_45\P37
# file Pressure_curves_ascii\L13_45\P41
# file Pressure_curves_ascii\L13_45\P45
# file Pressure_curves_ascii\L13_45\P49
# file Pressure_curves_ascii\L13_45\P5
# file Pressure_curves_ascii\L13_45\P53
# file Pressure_curves_ascii\L13_45\P57
# file Pressure_curves_ascii\L13_45\P59
# file Pressure_curves_ascii\L13_45\P9
# folder Pressure_curves_ascii\L13_47
# file Pressure_curves_ascii\L13_47\P1
# file Pressure_curves_ascii\L13_47\P13
# file Pressure_curves_ascii\L13_47\P17
# file Pressure_curves_ascii\L13_47\P21
# file Pressure_curves_ascii\L13_47\P25
# file Pressure_curves_ascii\L13_47\P29
# file Pressure_curves_ascii\L13_47\P33
# file Pressure_curves_ascii\L13_47\P37
# file Pressure_curves_ascii\L13_47\P41
# file Pressure_curves_ascii\L13_47\P45
# file Pressure_curves_ascii\L13_47\P49
# file Pressure_curves_ascii\L13_47\P5
# file Pressure_curves_ascii\L13_47\P53
# file Pressure_curves_ascii\L13_47\P57
# file Pressure_curves_ascii\L13_47\P59
# file Pressure_curves_ascii\L13_47\P9
# folder Pressure_curves_ascii\L13_49
# file Pressure_curves_ascii\L13_49\P1
# file Pressure_curves_ascii\L13_49\P13
# file Pressure_curves_ascii\L13_49\P17
# file Pressure_curves_ascii\L13_49\P21
# file Pressure_curves_ascii\L13_49\P25
# file Pressure_curves_ascii\L13_49\P29
# file Pressure_curves_ascii\L13_49\P33
# file Pressure_curves_ascii\L13_49\P37
# file Pressure_curves_ascii\L13_49\P41
# file Pressure_curves_ascii\L13_49\P45
# file Pressure_curves_ascii\L13_49\P49
# file Pressure_curves_ascii\L13_49\P5
# file Pressure_curves_ascii\L13_49\P53
# file Pressure_curves_ascii\L13_49\P57
# file Pressure_curves_ascii\L13_49\P59
# file Pressure_curves_ascii\L13_49\P9
# folder Pressure_curves_ascii\L13_5
# file Pressure_curves_ascii\L13_5\P1
# file Pressure_curves_ascii\L13_5\P13
# file Pressure_curves_ascii\L13_5\P17
# file Pressure_curves_ascii\L13_5\P21
# file Pressure_curves_ascii\L13_5\P25
# file Pressure_curves_ascii\L13_5\P29
# file Pressure_curves_ascii\L13_5\P33
# file Pressure_curves_ascii\L13_5\P37
# file Pressure_curves_ascii\L13_5\P41
# file Pressure_curves_ascii\L13_5\P45
# file Pressure_curves_ascii\L13_5\P49
# file Pressure_curves_ascii\L13_5\P5
# file Pressure_curves_ascii\L13_5\P53
# file Pressure_curves_ascii\L13_5\P57
# file Pressure_curves_ascii\L13_5\P59
# file Pressure_curves_ascii\L13_5\P9
# folder Pressure_curves_ascii\L13_51
# file Pressure_curves_ascii\L13_51\P1
# file Pressure_curves_ascii\L13_51\P13
# file Pressure_curves_ascii\L13_51\P17
# file Pressure_curves_ascii\L13_51\P21
# file Pressure_curves_ascii\L13_51\P25
# file Pressure_curves_ascii\L13_51\P29
# file Pressure_curves_ascii\L13_51\P33
# file Pressure_curves_ascii\L13_51\P37
# file Pressure_curves_ascii\L13_51\P41
# file Pressure_curves_ascii\L13_51\P45
# file Pressure_curves_ascii\L13_51\P49
# file Pressure_curves_ascii\L13_51\P5
# file Pressure_curves_ascii\L13_51\P53
# file Pressure_curves_ascii\L13_51\P57
# file Pressure_curves_ascii\L13_51\P59
# file Pressure_curves_ascii\L13_51\P9
# folder Pressure_curves_ascii\L13_53
# file Pressure_curves_ascii\L13_53\P1
# file Pressure_curves_ascii\L13_53\P13
# file Pressure_curves_ascii\L13_53\P17
# file Pressure_curves_ascii\L13_53\P21
# file Pressure_curves_ascii\L13_53\P25
# file Pressure_curves_ascii\L13_53\P29
# file Pressure_curves_ascii\L13_53\P33
# file Pressure_curves_ascii\L13_53\P37
# file Pressure_curves_ascii\L13_53\P41
# file Pressure_curves_ascii\L13_53\P45
# file Pressure_curves_ascii\L13_53\P49
# file Pressure_curves_ascii\L13_53\P5
# file Pressure_curves_ascii\L13_53\P53
# file Pressure_curves_ascii\L13_53\P57
# file Pressure_curves_ascii\L13_53\P59
# file Pressure_curves_ascii\L13_53\P9
# folder Pressure_curves_ascii\L13_55
# file Pressure_curves_ascii\L13_55\P1
# file Pressure_curves_ascii\L13_55\P13
# file Pressure_curves_ascii\L13_55\P17
# file Pressure_curves_ascii\L13_55\P21
# file Pressure_curves_ascii\L13_55\P25
# file Pressure_curves_ascii\L13_55\P29
# file Pressure_curves_ascii\L13_55\P33
# file Pressure_curves_ascii\L13_55\P37
# file Pressure_curves_ascii\L13_55\P41
# file Pressure_curves_ascii\L13_55\P45
# file Pressure_curves_ascii\L13_55\P49
# file Pressure_curves_ascii\L13_55\P5
# file Pressure_curves_ascii\L13_55\P53
# file Pressure_curves_ascii\L13_55\P57
# file Pressure_curves_ascii\L13_55\P59
# file Pressure_curves_ascii\L13_55\P9
# folder Pressure_curves_ascii\L13_57
# file Pressure_curves_ascii\L13_57\P1
# file Pressure_curves_ascii\L13_57\P13
# file Pressure_curves_ascii\L13_57\P17
# file Pressure_curves_ascii\L13_57\P21
# file Pressure_curves_ascii\L13_57\P25
# file Pressure_curves_ascii\L13_57\P29
# file Pressure_curves_ascii\L13_57\P33
# file Pressure_curves_ascii\L13_57\P37
# file Pressure_curves_ascii\L13_57\P41
# file Pressure_curves_ascii\L13_57\P45
# file Pressure_curves_ascii\L13_57\P49
# file Pressure_curves_ascii\L13_57\P5
# file Pressure_curves_ascii\L13_57\P53
# file Pressure_curves_ascii\L13_57\P57
# file Pressure_curves_ascii\L13_57\P59
# file Pressure_curves_ascii\L13_57\P9
# folder Pressure_curves_ascii\L13_59
# file Pressure_curves_ascii\L13_59\P1
# file Pressure_curves_ascii\L13_59\P13
# file Pressure_curves_ascii\L13_59\P17
# file Pressure_curves_ascii\L13_59\P21
# file Pressure_curves_ascii\L13_59\P25
# file Pressure_curves_ascii\L13_59\P29
# file Pressure_curves_ascii\L13_59\P33
# file Pressure_curves_ascii\L13_59\P37
# file Pressure_curves_ascii\L13_59\P41
# file Pressure_curves_ascii\L13_59\P45
# file Pressure_curves_ascii\L13_59\P49
# file Pressure_curves_ascii\L13_59\P5
# file Pressure_curves_ascii\L13_59\P53
# file Pressure_curves_ascii\L13_59\P57
# file Pressure_curves_ascii\L13_59\P59
# file Pressure_curves_ascii\L13_59\P9
# folder Pressure_curves_ascii\L13_61
# file Pressure_curves_ascii\L13_61\P1
# file Pressure_curves_ascii\L13_61\P13
# file Pressure_curves_ascii\L13_61\P17
# file Pressure_curves_ascii\L13_61\P21
# file Pressure_curves_ascii\L13_61\P25
# file Pressure_curves_ascii\L13_61\P29
# file Pressure_curves_ascii\L13_61\P33
# file Pressure_curves_ascii\L13_61\P37
# file Pressure_curves_ascii\L13_61\P41
# file Pressure_curves_ascii\L13_61\P45
# file Pressure_curves_ascii\L13_61\P49
# file Pressure_curves_ascii\L13_61\P5
# file Pressure_curves_ascii\L13_61\P53
# file Pressure_curves_ascii\L13_61\P57
# file Pressure_curves_ascii\L13_61\P59
# file Pressure_curves_ascii\L13_61\P9
# folder Pressure_curves_ascii\L13_63
# file Pressure_curves_ascii\L13_63\P1
# file Pressure_curves_ascii\L13_63\P13
# file Pressure_curves_ascii\L13_63\P17
# file Pressure_curves_ascii\L13_63\P21
# file Pressure_curves_ascii\L13_63\P25
# file Pressure_curves_ascii\L13_63\P29
# file Pressure_curves_ascii\L13_63\P33
# file Pressure_curves_ascii\L13_63\P37
# file Pressure_curves_ascii\L13_63\P41
# file Pressure_curves_ascii\L13_63\P45
# file Pressure_curves_ascii\L13_63\P49
# file Pressure_curves_ascii\L13_63\P5
# file Pressure_curves_ascii\L13_63\P53
# file Pressure_curves_ascii\L13_63\P57
# file Pressure_curves_ascii\L13_63\P59
# file Pressure_curves_ascii\L13_63\P9
# folder Pressure_curves_ascii\L13_65
# file Pressure_curves_ascii\L13_65\P1
# file Pressure_curves_ascii\L13_65\P13
# file Pressure_curves_ascii\L13_65\P17
# file Pressure_curves_ascii\L13_65\P21
# file Pressure_curves_ascii\L13_65\P25
# file Pressure_curves_ascii\L13_65\P29
# file Pressure_curves_ascii\L13_65\P33
# file Pressure_curves_ascii\L13_65\P37
# file Pressure_curves_ascii\L13_65\P41
# file Pressure_curves_ascii\L13_65\P45
# file Pressure_curves_ascii\L13_65\P49
# file Pressure_curves_ascii\L13_65\P5
# file Pressure_curves_ascii\L13_65\P53
# file Pressure_curves_ascii\L13_65\P57
# file Pressure_curves_ascii\L13_65\P59
# file Pressure_curves_ascii\L13_65\P9
# folder Pressure_curves_ascii\L13_67
# file Pressure_curves_ascii\L13_67\P1
# file Pressure_curves_ascii\L13_67\P13
# file Pressure_curves_ascii\L13_67\P17
# file Pressure_curves_ascii\L13_67\P21
# file Pressure_curves_ascii\L13_67\P25
# file Pressure_curves_ascii\L13_67\P29
# file Pressure_curves_ascii\L13_67\P33
# file Pressure_curves_ascii\L13_67\P37
# file Pressure_curves_ascii\L13_67\P41
# file Pressure_curves_ascii\L13_67\P45
# file Pressure_curves_ascii\L13_67\P49
# file Pressure_curves_ascii\L13_67\P5
# file Pressure_curves_ascii\L13_67\P53
# file Pressure_curves_ascii\L13_67\P57
# file Pressure_curves_ascii\L13_67\P59
# file Pressure_curves_ascii\L13_67\P9
# folder Pressure_curves_ascii\L13_69
# file Pressure_curves_ascii\L13_69\P1
# file Pressure_curves_ascii\L13_69\P13
# file Pressure_curves_ascii\L13_69\P17
# file Pressure_curves_ascii\L13_69\P21
# file Pressure_curves_ascii\L13_69\P25
# file Pressure_curves_ascii\L13_69\P29
# file Pressure_curves_ascii\L13_69\P33
# file Pressure_curves_ascii\L13_69\P37
# file Pressure_curves_ascii\L13_69\P41
# file Pressure_curves_ascii\L13_69\P45
# file Pressure_curves_ascii\L13_69\P49
# file Pressure_curves_ascii\L13_69\P5
# file Pressure_curves_ascii\L13_69\P53
# file Pressure_curves_ascii\L13_69\P57
# file Pressure_curves_ascii\L13_69\P59
# file Pressure_curves_ascii\L13_69\P9
# folder Pressure_curves_ascii\L13_7
# file Pressure_curves_ascii\L13_7\P1
# file Pressure_curves_ascii\L13_7\P13
# file Pressure_curves_ascii\L13_7\P17
# file Pressure_curves_ascii\L13_7\P21
# file Pressure_curves_ascii\L13_7\P25
# file Pressure_curves_ascii\L13_7\P29
# file Pressure_curves_ascii\L13_7\P33
# file Pressure_curves_ascii\L13_7\P37
# file Pressure_curves_ascii\L13_7\P41
# file Pressure_curves_ascii\L13_7\P45
# file Pressure_curves_ascii\L13_7\P49
# file Pressure_curves_ascii\L13_7\P5
# file Pressure_curves_ascii\L13_7\P53
# file Pressure_curves_ascii\L13_7\P57
# file Pressure_curves_ascii\L13_7\P59
# file Pressure_curves_ascii\L13_7\P9
# folder Pressure_curves_ascii\L13_70
# file Pressure_curves_ascii\L13_70\P1
# file Pressure_curves_ascii\L13_70\P13
# file Pressure_curves_ascii\L13_70\P17
# file Pressure_curves_ascii\L13_70\P21
# file Pressure_curves_ascii\L13_70\P25
# file Pressure_curves_ascii\L13_70\P29
# file Pressure_curves_ascii\L13_70\P33
# file Pressure_curves_ascii\L13_70\P37
# file Pressure_curves_ascii\L13_70\P41
# file Pressure_curves_ascii\L13_70\P45
# file Pressure_curves_ascii\L13_70\P49
# file Pressure_curves_ascii\L13_70\P5
# file Pressure_curves_ascii\L13_70\P53
# file Pressure_curves_ascii\L13_70\P57
# file Pressure_curves_ascii\L13_70\P59
# file Pressure_curves_ascii\L13_70\P9
# folder Pressure_curves_ascii\L13_9
# file Pressure_curves_ascii\L13_9\P1
# file Pressure_curves_ascii\L13_9\P13
# file Pressure_curves_ascii\L13_9\P17
# file Pressure_curves_ascii\L13_9\P21
# file Pressure_curves_ascii\L13_9\P25
# file Pressure_curves_ascii\L13_9\P29
# file Pressure_curves_ascii\L13_9\P33
# file Pressure_curves_ascii\L13_9\P37
# file Pressure_curves_ascii\L13_9\P41
# file Pressure_curves_ascii\L13_9\P45
# file Pressure_curves_ascii\L13_9\P49
# file Pressure_curves_ascii\L13_9\P5
# file Pressure_curves_ascii\L13_9\P53
# file Pressure_curves_ascii\L13_9\P57
# file Pressure_curves_ascii\L13_9\P59
# file Pressure_curves_ascii\L13_9\P9
#      Charge_mass Standoff_distance  Peak_Pressure  Peak_time
# 0            0.5                 1   591827.62500    0.00067
# 1            0.5                 7   113668.39844    0.01588
# 2            0.5                 9   110072.21094    0.02163
# 3            0.5                11   107787.85156    0.02743
# 4            0.5                13   106665.80469    0.03328
# ..           ...               ...            ...        ...
# 571          4.5                 3   302001.00000    0.00284
# 572          4.5                27   106685.08594    0.06909
# 573          4.5                29   106116.78906    0.07496
# 574          4.5                30   105965.99219    0.07789
# 575          4.5                 5   169580.00000    0.00713
#
# [576 rows x 4 columns]

# %% [markdown]
# # Create peak pressure file - Attempt 2 (with peak index)

# %% [markdown]
# ## Access input folders 2

# %%
#Access input folder
input_dir3 = Path ("Pressure_curves_excel_with_MinMaxTime")
print ("3",input_dir3)

#Access folders inside input folder
input_dir4 =  [folder for folder in input_dir3.iterdir() if folder.is_dir()]
print ("4",input_dir4)
# Out:
# 3 Pressure_curves_excel_with_MinMaxTime
# 4 [WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_1'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_11'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_13'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_15'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_17'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_19'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_21'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_23'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_25'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_27'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_29'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_3'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_31'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_33'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_35'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_37'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_39'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_41'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_43'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_45'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_47'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_49'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_5'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_51'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_53'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_55'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_57'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_59'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_61'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_63'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_65'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_67'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_69'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_7'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_70'), WindowsPath('Pressure_curves_excel_with_MinMaxTime/L13_9')]

# %% [markdown]
# ## Create peak pressure dataframe

# %%
df1 = pd.DataFrame(columns = ['Charge_mass', 'Standoff_distance', 'Peak pressure', 'Peak time', 'Peak index'])
# Access each folder inside input folder
for folder in input_dir4:
    print ("folder", folder)
    charge_mass = int(folder.stem[4:])/2
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
        
    # Access each file 
    for file in files:
        wrkbk = openpyxl.load_workbook(file)
        sh = wrkbk.active
        stand_dis = math.ceil(int(file.stem[1:])/2)
        peak_time = sh.cell(row = 2, column = 4)
        print ('file', file, 'peak_time', peak_time.value)
        
        # iterate through excel and display data
        for i in range(2, sh.max_row+1):
            cell_time = sh.cell (row = i, column = 1)
            #print (cell_time.value)
            if round(cell_time.value, 10) >= peak_time.value:
                print ("cell_time", cell_time.value)
                peak_index = i
                peak_pressure = sh.cell (row = i, column = 2)
                print ("peak_index", i, 'peak_pressure', peak_pressure.value)
                
                # append rows to an empty DataFrame
                new_row = {'Charge_mass' : [charge_mass],
                           'Standoff_distance' : [stand_dis],
                           'Peak pressure' : [peak_pressure.value],
                           'Peak time' : [peak_time.value],
                           'Peak index' : [i]}
                new_row_data = pd.DataFrame(new_row)
                df1 = pd.concat([df1, new_row_data], ignore_index = True)
                break
# Out:
# folder Pressure_curves_excel_with_MinMaxTime\L13_1
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P1.xlsx peak_time 0.0006695743
# cell_time 0.00066957430681
# peak_index 69 peak_pressure 591827.625
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P13.xlsx peak_time 0.0158798229
# cell_time 0.015879822895
# peak_index 1590 peak_pressure 113668.39844
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P17.xlsx peak_time 0.0216297656
# cell_time 0.02162976563
# peak_index 2165 peak_pressure 110072.21094
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P21.xlsx peak_time 0.0274298247
# cell_time 0.027429824695
# peak_index 2745 peak_pressure 107787.85156
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P25.xlsx peak_time 0.0332799591
# cell_time 0.033279959112
# peak_index 3330 peak_pressure 106665.80469
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P29.xlsx peak_time 0.0391499884
# cell_time 0.039149988443
# peak_index 3917 peak_pressure 105719.59375
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P33.xlsx peak_time 0.0450398661
# cell_time 0.04503986612
# peak_index 4506 peak_pressure 105030.91406
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P37.xlsx peak_time 0.0509396493
# cell_time 0.050939649343
# peak_index 5096 peak_pressure 104495.16406
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P41.xlsx peak_time 0.0568596721
# cell_time 0.05685967207
# peak_index 5688 peak_pressure 104108.375
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P45.xlsx peak_time 0.0627797693
# cell_time 0.062779769301
# peak_index 6280 peak_pressure 103792.02344
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P49.xlsx peak_time 0.0687097833
# cell_time 0.068709783256
# peak_index 6873 peak_pressure 103532.71094
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P5.xlsx peak_time 0.004899831
# cell_time 0.0048998310231
# peak_index 492 peak_pressure 147433.3125
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P53.xlsx peak_time 0.074649699
# cell_time 0.074649699032
# peak_index 7467 peak_pressure 103316.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P57.xlsx peak_time 0.0805896148
# cell_time 0.080589614809
# peak_index 8061 peak_pressure 103137.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P59.xlsx peak_time 0.0835597888
# cell_time 0.083559788764
# peak_index 8358 peak_pressure 103058.85156
# file Pressure_curves_excel_with_MinMaxTime\L13_1\P9.xlsx peak_time 0.0102696139
# cell_time 0.010269613937
# peak_index 1029 peak_pressure 121033.5625
# folder Pressure_curves_excel_with_MinMaxTime\L13_11
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P1.xlsx peak_time 0.0003499947
# cell_time 0.00034999471973
# peak_index 37 peak_pressure 2829861.75
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P13.xlsx peak_time 0.0117299976
# cell_time 0.011729997583
# peak_index 1175 peak_pressure 143638.5
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P17.xlsx peak_time 0.0170197971
# cell_time 0.017019797117
# peak_index 1704 peak_pressure 128861.65625
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P21.xlsx peak_time 0.0224798732
# cell_time 0.022479873151
# peak_index 2250 peak_pressure 121571.08594
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P25.xlsx peak_time 0.0280599836
# cell_time 0.028059983626
# peak_index 2808 peak_pressure 117100.38281
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P29.xlsx peak_time 0.0336997099
# cell_time 0.033699709922
# peak_index 3372 peak_pressure 114680.77344
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P33.xlsx peak_time 0.0394097529
# cell_time 0.039409752935
# peak_index 3943 peak_pressure 112516.38281
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P37.xlsx peak_time 0.045159813
# cell_time 0.045159813017
# peak_index 4518 peak_pressure 110880.39844
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P41.xlsx peak_time 0.0509399362
# cell_time 0.050939936191
# peak_index 5096 peak_pressure 109635.44531
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P45.xlsx peak_time 0.0567399152
# cell_time 0.056739915162
# peak_index 5676 peak_pressure 108501.60156
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P49.xlsx peak_time 0.0625699088
# cell_time 0.062569908798
# peak_index 6259 peak_pressure 107717.88281
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P5.xlsx peak_time 0.0026698834
# cell_time 0.0026698834263
# peak_index 269 peak_pressure 336005.84375
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P53.xlsx peak_time 0.0684099421
# cell_time 0.068409942091
# peak_index 6843 peak_pressure 107071.42969
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P57.xlsx peak_time 0.074259907
# cell_time 0.074259907007
# peak_index 7428 peak_pressure 106645.21875
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P59.xlsx peak_time 0.0771899819
# cell_time 0.077189981937
# peak_index 7721 peak_pressure 106414.59375
# file Pressure_curves_excel_with_MinMaxTime\L13_11\P9.xlsx peak_time 0.0068097934
# cell_time 0.0068097934127
# peak_index 683 peak_pressure 179013.375
# folder Pressure_curves_excel_with_MinMaxTime\L13_13
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P1.xlsx peak_time 0.0003399208
# cell_time 0.00033992077806
# peak_index 36 peak_pressure 2992145
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P13.xlsx peak_time 0.0113699259
# cell_time 0.011369925924
# peak_index 1139 peak_pressure 148183.46875
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P17.xlsx peak_time 0.016589852
# cell_time 0.01658985205
# peak_index 1661 peak_pressure 132251.09375
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P21.xlsx peak_time 0.0220097322
# cell_time 0.022009732202
# peak_index 2203 peak_pressure 124138.66406
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P25.xlsx peak_time 0.0275599249
# cell_time 0.027559924871
# peak_index 2758 peak_pressure 118614.9375
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P29.xlsx peak_time 0.0331899673
# cell_time 0.033189967275
# peak_index 3321 peak_pressure 115248.66406
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P33.xlsx peak_time 0.0388898216
# cell_time 0.038889821619
# peak_index 3891 peak_pressure 112934.15625
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P37.xlsx peak_time 0.0446098968
# cell_time 0.044609896839
# peak_index 4463 peak_pressure 111188.94531
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P41.xlsx peak_time 0.0503698885
# cell_time 0.050369888544
# peak_index 5039 peak_pressure 110319.85156
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P45.xlsx peak_time 0.0561597422
# cell_time 0.056159742177
# peak_index 5618 peak_pressure 109262.46875
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P49.xlsx peak_time 0.0619698688
# cell_time 0.061969868839
# peak_index 6199 peak_pressure 108399.96094
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P5.xlsx peak_time 0.0025299243
# cell_time 0.0025299242698
# peak_index 255 peak_pressure 370790.09375
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P53.xlsx peak_time 0.0677998215
# cell_time 0.067799821496
# peak_index 6782 peak_pressure 107654.19531
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P57.xlsx peak_time 0.0736399516
# cell_time 0.073639951646
# peak_index 7366 peak_pressure 107088.58594
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P59.xlsx peak_time 0.0765698999
# cell_time 0.076569899917
# peak_index 7659 peak_pressure 106774.46094
# file Pressure_curves_excel_with_MinMaxTime\L13_13\P9.xlsx peak_time 0.0065397299
# cell_time 0.0065397298895
# peak_index 656 peak_pressure 188203.82812
# folder Pressure_curves_excel_with_MinMaxTime\L13_15
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P1.xlsx peak_time 0.0003199522
# cell_time 0.00031995220343
# peak_index 34 peak_pressure 3619006.25
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P13.xlsx peak_time 0.0110698305
# cell_time 0.011069830507
# peak_index 1109 peak_pressure 152542.29688
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P17.xlsx peak_time 0.0162499864
# cell_time 0.016249986365
# peak_index 1627 peak_pressure 133983.54688
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P21.xlsx peak_time 0.0216198247
# cell_time 0.021619824693
# peak_index 2164 peak_pressure 125835.49219
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P25.xlsx peak_time 0.0271398276
# cell_time 0.027139827609
# peak_index 2716 peak_pressure 119999.02344
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P29.xlsx peak_time 0.0327599049
# cell_time 0.032759904861
# peak_index 3278 peak_pressure 116213.16406
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P33.xlsx peak_time 0.0384099782
# cell_time 0.038409978151
# peak_index 3843 peak_pressure 114124.22656
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P37.xlsx peak_time 0.0441299118
# cell_time 0.04412991181
# peak_index 4415 peak_pressure 112080.05469
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P41.xlsx peak_time 0.0498797707
# cell_time 0.049879770726
# peak_index 4990 peak_pressure 110711.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P45.xlsx peak_time 0.0556799769
# cell_time 0.05567997694
# peak_index 5570 peak_pressure 109415.83594
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P49.xlsx peak_time 0.0614498518
# cell_time 0.061449851841
# peak_index 6147 peak_pressure 108630.40625
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P5.xlsx peak_time 0.0024197993
# cell_time 0.0024197993334
# peak_index 244 peak_pressure 403127.375
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P53.xlsx peak_time 0.0672697201
# cell_time 0.067269720137
# peak_index 6729 peak_pressure 108055.60156
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P57.xlsx peak_time 0.0731099322
# cell_time 0.073109932244
# peak_index 7313 peak_pressure 107345.36719
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P59.xlsx peak_time 0.0760297924
# cell_time 0.076029792428
# peak_index 7605 peak_pressure 107162.53125
# file Pressure_curves_excel_with_MinMaxTime\L13_15\P9.xlsx peak_time 0.0063097682
# cell_time 0.006309768185
# peak_index 633 peak_pressure 197055.07812
# folder Pressure_curves_excel_with_MinMaxTime\L13_17
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P1.xlsx peak_time 0.0003199682
# cell_time 0.00031996815233
# peak_index 34 peak_pressure 3508771
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P13.xlsx peak_time 0.0107997674
# cell_time 0.010799767449
# peak_index 1082 peak_pressure 155607.51562
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P17.xlsx peak_time 0.015929928
# cell_time 0.015929928049
# peak_index 1595 peak_pressure 136290.40625
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P21.xlsx peak_time 0.021259835
# cell_time 0.02125983499
# peak_index 2128 peak_pressure 127017.16406
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P25.xlsx peak_time 0.0267498046
# cell_time 0.026749804616
# peak_index 2677 peak_pressure 121284.66406
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P29.xlsx peak_time 0.0323499292
# cell_time 0.032349929214
# peak_index 3237 peak_pressure 117158.86719
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P33.xlsx peak_time 0.0379899181
# cell_time 0.037989918143
# peak_index 3801 peak_pressure 114509.38281
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P37.xlsx peak_time 0.0436998941
# cell_time 0.0436998941
# peak_index 4372 peak_pressure 112545.125
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P41.xlsx peak_time 0.0494197346
# cell_time 0.049419734627
# peak_index 4944 peak_pressure 111462.0625
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P45.xlsx peak_time 0.0551898889
# cell_time 0.055189888924
# peak_index 5521 peak_pressure 110178.4375
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P49.xlsx peak_time 0.0609798543
# cell_time 0.060979854316
# peak_index 6100 peak_pressure 109122.13281
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P5.xlsx peak_time 0.0023196854
# cell_time 0.0023196854163
# peak_index 234 peak_pressure 439089.90625
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P53.xlsx peak_time 0.0667898804
# cell_time 0.066789880395
# peak_index 6681 peak_pressure 108280.33594
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P57.xlsx peak_time 0.0726096854
# cell_time 0.072609685361
# peak_index 7263 peak_pressure 107842.84375
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P59.xlsx peak_time 0.0755299851
# cell_time 0.07552998513
# peak_index 7555 peak_pressure 107520.41406
# file Pressure_curves_excel_with_MinMaxTime\L13_17\P9.xlsx peak_time 0.0061099078
# cell_time 0.0061099077575
# peak_index 613 peak_pressure 205507
# folder Pressure_curves_excel_with_MinMaxTime\L13_19
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P1.xlsx peak_time 0.0003099937
# cell_time 0.00030999374576
# peak_index 33 peak_pressure 3868159.75
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P13.xlsx peak_time 0.0105598159
# cell_time 0.010559815913
# peak_index 1058 peak_pressure 159387.875
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P17.xlsx peak_time 0.0156299844
# cell_time 0.015629984438
# peak_index 1565 peak_pressure 139244.6875
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P21.xlsx peak_time 0.020959774
# cell_time 0.020959774032
# peak_index 2098 peak_pressure 128144.6875
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P25.xlsx peak_time 0.0264097545
# cell_time 0.02640975453
# peak_index 2643 peak_pressure 122728.28125
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P29.xlsx peak_time 0.0319898501
# cell_time 0.031989850104
# peak_index 3201 peak_pressure 118014.47656
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P33.xlsx peak_time 0.0376098044
# cell_time 0.037609804422
# peak_index 3763 peak_pressure 115263.09375
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P37.xlsx peak_time 0.0432897396
# cell_time 0.043289739639
# peak_index 4331 peak_pressure 113667.30469
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P41.xlsx peak_time 0.0490299128
# cell_time 0.0490299128
# peak_index 4905 peak_pressure 111558.78906
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P45.xlsx peak_time 0.0547697544
# cell_time 0.05476975441
# peak_index 5479 peak_pressure 110787.125
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P49.xlsx peak_time 0.0605499707
# cell_time 0.060549970716
# peak_index 6057 peak_pressure 109729.625
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P5.xlsx peak_time 0.0022396436
# cell_time 0.0022396435961
# peak_index 226 peak_pressure 471456.59375
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P53.xlsx peak_time 0.0663497671
# cell_time 0.066349767148
# peak_index 6637 peak_pressure 108893.53906
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P57.xlsx peak_time 0.072169818
# cell_time 0.072169817984
# peak_index 7219 peak_pressure 108089.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P59.xlsx peak_time 0.0750797242
# cell_time 0.075079724193
# peak_index 7510 peak_pressure 107850.21094
# file Pressure_curves_excel_with_MinMaxTime\L13_19\P9.xlsx peak_time 0.0059298552
# cell_time 0.0059298551641
# peak_index 595 peak_pressure 214846.01562
# folder Pressure_curves_excel_with_MinMaxTime\L13_21
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P1.xlsx peak_time 0.0002999791
# cell_time 0.0002999791468
# peak_index 32 peak_pressure 4301432
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P13.xlsx peak_time 0.0103298416
# cell_time 0.010329841636
# peak_index 1035 peak_pressure 163628.60938
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P17.xlsx peak_time 0.0153598739
# cell_time 0.015359873883
# peak_index 1538 peak_pressure 141733.1875
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P21.xlsx peak_time 0.0206597578
# cell_time 0.020659757778
# peak_index 2068 peak_pressure 129617.77344
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P25.xlsx peak_time 0.0260997098
# cell_time 0.026099709794
# peak_index 2612 peak_pressure 123111.9375
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P29.xlsx peak_time 0.0316298679
# cell_time 0.031629867852
# peak_index 3165 peak_pressure 119140.875
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P33.xlsx peak_time 0.037259955
# cell_time 0.037259954959
# peak_index 3728 peak_pressure 115955.65625
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P37.xlsx peak_time 0.0429297127
# cell_time 0.042929712683
# peak_index 4295 peak_pressure 113761.14844
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P41.xlsx peak_time 0.0486299656
# cell_time 0.048629965633
# peak_index 4865 peak_pressure 112298.78906
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P45.xlsx peak_time 0.0543698482
# cell_time 0.054369848222
# peak_index 5439 peak_pressure 111199.75
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P49.xlsx peak_time 0.0601398796
# cell_time 0.060139879584
# peak_index 6016 peak_pressure 110137.92969
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P5.xlsx peak_time 0.0021699471
# cell_time 0.0021699471399
# peak_index 219 peak_pressure 502720.96875
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P53.xlsx peak_time 0.065929912
# cell_time 0.065929912031
# peak_index 6595 peak_pressure 109083.14844
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P57.xlsx peak_time 0.0717398748
# cell_time 0.07173987478
# peak_index 7176 peak_pressure 108388.6875
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P59.xlsx peak_time 0.0746499076
# cell_time 0.074649907649
# peak_index 7467 peak_pressure 107998.25
# file Pressure_curves_excel_with_MinMaxTime\L13_21\P9.xlsx peak_time 0.0057698069
# cell_time 0.005769806914
# peak_index 579 peak_pressure 222743.64062
# folder Pressure_curves_excel_with_MinMaxTime\L13_23
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P1.xlsx peak_time 0.000299992
# cell_time 0.0002999920107
# peak_index 32 peak_pressure 4192531.25
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P13.xlsx peak_time 0.0101298457
# cell_time 0.010129845701
# peak_index 1015 peak_pressure 167086.8125
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P17.xlsx peak_time 0.0151297823
# cell_time 0.015129782259
# peak_index 1515 peak_pressure 142889.45312
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P21.xlsx peak_time 0.0203698203
# cell_time 0.020369820297
# peak_index 2039 peak_pressure 131802.46875
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P25.xlsx peak_time 0.0257997494
# cell_time 0.025799749419
# peak_index 2582 peak_pressure 124211.78125
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P29.xlsx peak_time 0.031309817
# cell_time 0.031309816986
# peak_index 3133 peak_pressure 120414.52344
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P33.xlsx peak_time 0.0369098522
# cell_time 0.036909852177
# peak_index 3693 peak_pressure 117068.5625
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P37.xlsx peak_time 0.0425696932
# cell_time 0.042569693178
# peak_index 4259 peak_pressure 114866.78125
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P41.xlsx peak_time 0.0482699685
# cell_time 0.04826996848
# peak_index 4829 peak_pressure 113092.1875
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P45.xlsx peak_time 0.054019969
# cell_time 0.054019968957
# peak_index 5404 peak_pressure 111199.96094
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P49.xlsx peak_time 0.0597698204
# cell_time 0.059769820422
# peak_index 5979 peak_pressure 110176.91406
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P5.xlsx peak_time 0.0020996472
# cell_time 0.0020996471867
# peak_index 212 peak_pressure 541649.125
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P53.xlsx peak_time 0.065549843
# cell_time 0.065549843013
# peak_index 6557 peak_pressure 109598.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P57.xlsx peak_time 0.0713499635
# cell_time 0.071349963546
# peak_index 7137 peak_pressure 108767.63281
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P59.xlsx peak_time 0.0742597058
# cell_time 0.074259705842
# peak_index 7428 peak_pressure 108478.53906
# file Pressure_curves_excel_with_MinMaxTime\L13_23\P9.xlsx peak_time 0.005629939
# cell_time 0.0056299390271
# peak_index 565 peak_pressure 230325.6875
# folder Pressure_curves_excel_with_MinMaxTime\L13_25
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P1.xlsx peak_time 0.0002899173
# cell_time 0.00028991734143
# peak_index 31 peak_pressure 4723623.5
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P13.xlsx peak_time 0.009949957
# cell_time 0.0099499570206
# peak_index 997 peak_pressure 170277.01562
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P17.xlsx peak_time 0.014899753
# cell_time 0.014899753034
# peak_index 1492 peak_pressure 144927.9375
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P21.xlsx peak_time 0.0201197658
# cell_time 0.020119765773
# peak_index 2014 peak_pressure 132789.3125
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P25.xlsx peak_time 0.0255198516
# cell_time 0.025519851595
# peak_index 2554 peak_pressure 125288.82031
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P29.xlsx peak_time 0.0310398806
# cell_time 0.031039880589
# peak_index 3106 peak_pressure 120493.78125
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P33.xlsx peak_time 0.0366099328
# cell_time 0.03660993278
# peak_index 3663 peak_pressure 117775.77344
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P37.xlsx peak_time 0.0422596969
# cell_time 0.042259696871
# peak_index 4228 peak_pressure 115051.65625
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P41.xlsx peak_time 0.0479498133
# cell_time 0.047949813306
# peak_index 4797 peak_pressure 113265.88281
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P45.xlsx peak_time 0.0536699146
# cell_time 0.053669914603
# peak_index 5369 peak_pressure 111895.66406
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P49.xlsx peak_time 0.0594298802
# cell_time 0.059429880232
# peak_index 5945 peak_pressure 110466.27344
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P5.xlsx peak_time 0.0020497364
# cell_time 0.0020497364458
# peak_index 207 peak_pressure 569585
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P53.xlsx peak_time 0.0651997179
# cell_time 0.065199717879
# peak_index 6522 peak_pressure 109846.28906
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P57.xlsx peak_time 0.0709998086
# cell_time 0.070999808609
# peak_index 7102 peak_pressure 109045.35156
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P59.xlsx peak_time 0.073899895
# cell_time 0.073899894953
# peak_index 7392 peak_pressure 108688.10156
# file Pressure_curves_excel_with_MinMaxTime\L13_25\P9.xlsx peak_time 0.0054997923
# cell_time 0.0054997922853
# peak_index 552 peak_pressure 238363.67188
# folder Pressure_curves_excel_with_MinMaxTime\L13_27
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P1.xlsx peak_time 0.000289983
# cell_time 0.00028998302878
# peak_index 31 peak_pressure 4629516
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P13.xlsx peak_time 0.0097798808
# cell_time 0.0097798807546
# peak_index 980 peak_pressure 173762.67188
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P17.xlsx peak_time 0.0146897817
# cell_time 0.014689781703
# peak_index 1471 peak_pressure 147813.71875
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P21.xlsx peak_time 0.0198898464
# cell_time 0.019889846444
# peak_index 1991 peak_pressure 134271.375
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P25.xlsx peak_time 0.0252598617
# cell_time 0.025259861723
# peak_index 2528 peak_pressure 126232.16406
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P29.xlsx peak_time 0.0307697523
# cell_time 0.030769752339
# peak_index 3079 peak_pressure 121208.22656
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P33.xlsx peak_time 0.0363399573
# cell_time 0.036339957267
# peak_index 3636 peak_pressure 117848.5625
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P37.xlsx peak_time 0.0419599935
# cell_time 0.041959993541
# peak_index 4198 peak_pressure 115935.96094
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P41.xlsx peak_time 0.0476398394
# cell_time 0.047639839351
# peak_index 4766 peak_pressure 114000.39844
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P45.xlsx peak_time 0.0533598214
# cell_time 0.053359821439
# peak_index 5338 peak_pressure 112117.09375
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P49.xlsx peak_time 0.0590997674
# cell_time 0.059099767357
# peak_index 5912 peak_pressure 111209.85156
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P5.xlsx peak_time 0.0019997556
# cell_time 0.0019997556228
# peak_index 202 peak_pressure 601990.0625
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P53.xlsx peak_time 0.0648699328
# cell_time 0.06486993283
# peak_index 6489 peak_pressure 110228.14844
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P57.xlsx peak_time 0.0706598163
# cell_time 0.070659816265
# peak_index 7068 peak_pressure 109391.11719
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P59.xlsx peak_time 0.073559761
# cell_time 0.073559761047
# peak_index 7358 peak_pressure 108971.3125
# file Pressure_curves_excel_with_MinMaxTime\L13_27\P9.xlsx peak_time 0.0053799385
# cell_time 0.0053799385205
# peak_index 540 peak_pressure 246499.39062
# folder Pressure_curves_excel_with_MinMaxTime\L13_29
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P1.xlsx peak_time 0.0002799131
# cell_time 0.00027991313254
# peak_index 30 peak_pressure 5259944.5
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P13.xlsx peak_time 0.0096197044
# cell_time 0.0096197044477
# peak_index 964 peak_pressure 177385.0625
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P17.xlsx peak_time 0.0145099415
# cell_time 0.014509941451
# peak_index 1453 peak_pressure 148804.82812
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P21.xlsx peak_time 0.0196697824
# cell_time 0.01966978237
# peak_index 1969 peak_pressure 135571.23438
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P25.xlsx peak_time 0.0250197351
# cell_time 0.025019735098
# peak_index 2504 peak_pressure 127194.375
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P29.xlsx peak_time 0.0304996986
# cell_time 0.030499698594
# peak_index 3052 peak_pressure 122097.19531
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P33.xlsx peak_time 0.0360599197
# cell_time 0.036059919745
# peak_index 3608 peak_pressure 118440.34375
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P37.xlsx peak_time 0.0416798703
# cell_time 0.041679870337
# peak_index 4170 peak_pressure 116348.96875
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P41.xlsx peak_time 0.047349941
# cell_time 0.047349940985
# peak_index 4737 peak_pressure 114370.53906
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P45.xlsx peak_time 0.0530599691
# cell_time 0.053059969097
# peak_index 5308 peak_pressure 112530.64844
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P49.xlsx peak_time 0.0588097647
# cell_time 0.058809764683
# peak_index 5883 peak_pressure 111111.17969
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P5.xlsx peak_time 0.0019598058
# cell_time 0.0019598058425
# peak_index 198 peak_pressure 627336.625
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P53.xlsx peak_time 0.064559795
# cell_time 0.064559794962
# peak_index 6458 peak_pressure 110341.85156
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P57.xlsx peak_time 0.0703397915
# cell_time 0.070339791477
# peak_index 7036 peak_pressure 109660.71094
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P59.xlsx peak_time 0.0732397288
# cell_time 0.073239728808
# peak_index 7326 peak_pressure 109255.94531
# file Pressure_curves_excel_with_MinMaxTime\L13_29\P9.xlsx peak_time 0.0052697887
# cell_time 0.0052697886713
# peak_index 529 peak_pressure 254637.45312
# folder Pressure_curves_excel_with_MinMaxTime\L13_3
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P1.xlsx peak_time 0.00047991
# cell_time 0.00047990999883
# peak_index 50 peak_pressure 1347380
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P13.xlsx peak_time 0.0142099997
# cell_time 0.014209999703
# peak_index 1423 peak_pressure 122318
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P17.xlsx peak_time 0.0197999999
# cell_time 0.019799999893
# peak_index 1982 peak_pressure 116212
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P21.xlsx peak_time 0.0255100001
# cell_time 0.025510000065
# peak_index 2553 peak_pressure 111979
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P25.xlsx peak_time 0.03125
# cell_time 0.03125
# peak_index 3127 peak_pressure 109932
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P29.xlsx peak_time 0.0370500013
# cell_time 0.037050001323
# peak_index 3707 peak_pressure 108435
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P33.xlsx peak_time 0.0428799987
# cell_time 0.042879998684
# peak_index 4290 peak_pressure 107339
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P37.xlsx peak_time 0.0487399995
# cell_time 0.048739999533
# peak_index 4876 peak_pressure 106457
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P41.xlsx peak_time 0.0546099991
# cell_time 0.054609999061
# peak_index 5463 peak_pressure 105808
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P45.xlsx peak_time 0.060490001
# cell_time 0.060490000993
# peak_index 6051 peak_pressure 105349
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P49.xlsx peak_time 0.06637986
# cell_time 0.066379860044
# peak_index 6640 peak_pressure 104935.10156
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P5.xlsx peak_time 0.0038697999
# cell_time 0.0038697998971
# peak_index 389 peak_pressure 191345
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P53.xlsx peak_time 0.0722797662
# cell_time 0.072279766202
# peak_index 7230 peak_pressure 104562.03125
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P57.xlsx peak_time 0.0781896338
# cell_time 0.078189633787
# peak_index 7821 peak_pressure 104261.14844
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P59.xlsx peak_time 0.0811497346
# cell_time 0.081149734557
# peak_index 8117 peak_pressure 104146.02344
# file Pressure_curves_excel_with_MinMaxTime\L13_3\P9.xlsx peak_time 0.0088098003
# cell_time 0.0088098002598
# peak_index 883 peak_pressure 137016
# folder Pressure_curves_excel_with_MinMaxTime\L13_31
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P1.xlsx peak_time 0.0002799125
# cell_time 0.00027991249226
# peak_index 30 peak_pressure 5179066.5
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P13.xlsx peak_time 0.0094699161
# cell_time 0.0094699161127
# peak_index 949 peak_pressure 180604.67188
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P17.xlsx peak_time 0.0143097388
# cell_time 0.014309738763
# peak_index 1433 peak_pressure 150788.59375
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P21.xlsx peak_time 0.0194497593
# cell_time 0.019449759275
# peak_index 1947 peak_pressure 136718.85938
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P25.xlsx peak_time 0.0247999839
# cell_time 0.024799983948
# peak_index 2482 peak_pressure 128049.96094
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P29.xlsx peak_time 0.0302598309
# cell_time 0.030259830877
# peak_index 3028 peak_pressure 122685.30469
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P33.xlsx peak_time 0.0357897095
# cell_time 0.035789709538
# peak_index 3581 peak_pressure 119703.14844
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P37.xlsx peak_time 0.0413997881
# cell_time 0.041399788111
# peak_index 4142 peak_pressure 116931.96875
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P41.xlsx peak_time 0.0470598415
# cell_time 0.047059841454
# peak_index 4708 peak_pressure 114818.19531
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P45.xlsx peak_time 0.0527599864
# cell_time 0.052759986371
# peak_index 5278 peak_pressure 113232.75781
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P49.xlsx peak_time 0.0584898628
# cell_time 0.058489862829
# peak_index 5851 peak_pressure 111914.13281
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P5.xlsx peak_time 0.0019097509
# cell_time 0.001909750863
# peak_index 193 peak_pressure 671450.9375
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P53.xlsx peak_time 0.0642497912
# cell_time 0.064249791205
# peak_index 6427 peak_pressure 110517.02344
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P57.xlsx peak_time 0.0700199604
# cell_time 0.070019960403
# peak_index 7004 peak_pressure 109702.34375
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P59.xlsx peak_time 0.0729196966
# cell_time 0.072919696569
# peak_index 7294 peak_pressure 109512.28125
# file Pressure_curves_excel_with_MinMaxTime\L13_31\P9.xlsx peak_time 0.005169963
# cell_time 0.0051699629985
# peak_index 519 peak_pressure 261836.35938
# folder Pressure_curves_excel_with_MinMaxTime\L13_33
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P1.xlsx peak_time 0.0002799993
# cell_time 0.00027999927988
# peak_index 30 peak_pressure 5100407.5
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P13.xlsx peak_time 0.0093299458
# cell_time 0.0093299457803
# peak_index 935 peak_pressure 183884.75
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P17.xlsx peak_time 0.0141397743
# cell_time 0.014139774255
# peak_index 1416 peak_pressure 152670.90625
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P21.xlsx peak_time 0.0192698054
# cell_time 0.019269805402
# peak_index 1929 peak_pressure 137628.48438
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P25.xlsx peak_time 0.0245697629
# cell_time 0.024569762871
# peak_index 2459 peak_pressure 129425.11719
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P29.xlsx peak_time 0.03002996
# cell_time 0.030029959977
# peak_index 3005 peak_pressure 123397.77344
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P33.xlsx peak_time 0.035549771
# cell_time 0.035549771041
# peak_index 3557 peak_pressure 120125.35156
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P37.xlsx peak_time 0.0411497168
# cell_time 0.041149716824
# peak_index 4117 peak_pressure 117371.60156
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P41.xlsx peak_time 0.0467998572
# cell_time 0.046799857169
# peak_index 4682 peak_pressure 115274.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P45.xlsx peak_time 0.0524899326
# cell_time 0.052489932626
# peak_index 5251 peak_pressure 113501.58594
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P49.xlsx peak_time 0.058229696
# cell_time 0.058229696006
# peak_index 5825 peak_pressure 111742.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P5.xlsx peak_time 0.0018799343
# cell_time 0.0018799343379
# peak_index 190 peak_pressure 690562.625
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P53.xlsx peak_time 0.0639797896
# cell_time 0.063979789615
# peak_index 6400 peak_pressure 110665.02344
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P57.xlsx peak_time 0.0697397962
# cell_time 0.069739796221
# peak_index 6976 peak_pressure 109840.22656
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P59.xlsx peak_time 0.0726297721
# cell_time 0.072629772127
# peak_index 7265 peak_pressure 109719.53125
# file Pressure_curves_excel_with_MinMaxTime\L13_33\P9.xlsx peak_time 0.0050698356
# cell_time 0.0050698355772
# peak_index 509 peak_pressure 270808.625
# folder Pressure_curves_excel_with_MinMaxTime\L13_35
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P1.xlsx peak_time 0.0002699122
# cell_time 0.00026991218328
# peak_index 29 peak_pressure 5842436.5
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P13.xlsx peak_time 0.0091899401
# cell_time 0.0091899400577
# peak_index 921 peak_pressure 187806.85938
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P17.xlsx peak_time 0.0139698442
# cell_time 0.013969844207
# peak_index 1399 peak_pressure 154657.07812
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P21.xlsx peak_time 0.0190797541
# cell_time 0.019079754129
# peak_index 1910 peak_pressure 138824.60938
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P25.xlsx peak_time 0.0243599489
# cell_time 0.024359948933
# peak_index 2438 peak_pressure 130579.69531
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P29.xlsx peak_time 0.0297898781
# cell_time 0.029789878055
# peak_index 2981 peak_pressure 124794.84375
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P33.xlsx peak_time 0.0353098474
# cell_time 0.035309847444
# peak_index 3533 peak_pressure 120823
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P37.xlsx peak_time 0.04089991
# cell_time 0.040899910033
# peak_index 4092 peak_pressure 117903.91406
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P41.xlsx peak_time 0.0465397984
# cell_time 0.046539798379
# peak_index 4656 peak_pressure 115230.57031
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P45.xlsx peak_time 0.0522299185
# cell_time 0.05222991854
# peak_index 5225 peak_pressure 113425.13281
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P49.xlsx peak_time 0.0579398349
# cell_time 0.057939834893
# peak_index 5796 peak_pressure 112468.83594
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P5.xlsx peak_time 0.0018397139
# cell_time 0.001839713892
# peak_index 186 peak_pressure 730446.5625
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P53.xlsx peak_time 0.0636999905
# cell_time 0.063699990511
# peak_index 6372 peak_pressure 110905.94531
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P57.xlsx peak_time 0.0694498867
# cell_time 0.06944988668
# peak_index 6947 peak_pressure 110428.64844
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P59.xlsx peak_time 0.0723399594
# cell_time 0.072339959443
# peak_index 7236 peak_pressure 110004.69531
# file Pressure_curves_excel_with_MinMaxTime\L13_35\P9.xlsx peak_time 0.0049798498
# cell_time 0.004979849793
# peak_index 500 peak_pressure 278516.8125
# folder Pressure_curves_excel_with_MinMaxTime\L13_37
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P1.xlsx peak_time 0.0002699915
# cell_time 0.00026999152033
# peak_index 29 peak_pressure 5765450.5
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P13.xlsx peak_time 0.0090698237
# cell_time 0.00906982366
# peak_index 909 peak_pressure 190504.32812
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P17.xlsx peak_time 0.0138099734
# cell_time 0.013809973374
# peak_index 1383 peak_pressure 157363.78125
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P21.xlsx peak_time 0.0188997015
# cell_time 0.018899701536
# peak_index 1892 peak_pressure 140058.53125
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P25.xlsx peak_time 0.0241797119
# cell_time 0.024179711938
# peak_index 2420 peak_pressure 130682.83594
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P29.xlsx peak_time 0.0295799635
# cell_time 0.029579963535
# peak_index 2960 peak_pressure 125249.58594
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P33.xlsx peak_time 0.0350899361
# cell_time 0.035089936107
# peak_index 3511 peak_pressure 121003.83594
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P37.xlsx peak_time 0.04066981
# cell_time 0.040669810027
# peak_index 4069 peak_pressure 118026.63281
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P41.xlsx peak_time 0.0462998189
# cell_time 0.046299818903
# peak_index 4632 peak_pressure 116010.16406
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P45.xlsx peak_time 0.0519797131
# cell_time 0.051979713142
# peak_index 5200 peak_pressure 113941
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P49.xlsx peak_time 0.0576899648
# cell_time 0.057689964771
# peak_index 5771 peak_pressure 112324.88281
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P5.xlsx peak_time 0.0018099381
# cell_time 0.0018099381123
# peak_index 183 peak_pressure 757855.8125
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P53.xlsx peak_time 0.0634198487
# cell_time 0.06341984868
# peak_index 6344 peak_pressure 111346.3125
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P57.xlsx peak_time 0.0691797659
# cell_time 0.06917976588
# peak_index 6920 peak_pressure 110306.63281
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P59.xlsx peak_time 0.0720697194
# cell_time 0.072069719434
# peak_index 7209 peak_pressure 110212.71094
# file Pressure_curves_excel_with_MinMaxTime\L13_37\P9.xlsx peak_time 0.004899811
# cell_time 0.0048998109996
# peak_index 492 peak_pressure 285496.4375
# folder Pressure_curves_excel_with_MinMaxTime\L13_39
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P1.xlsx peak_time 0.0002699836
# cell_time 0.00026998357498
# peak_index 29 peak_pressure 5711491.5
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P13.xlsx peak_time 0.0089498116
# cell_time 0.0089498115703
# peak_index 897 peak_pressure 193730.4375
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P17.xlsx peak_time 0.0136698987
# cell_time 0.013669898733
# peak_index 1369 peak_pressure 158200.92188
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P21.xlsx peak_time 0.0187197682
# cell_time 0.018719768152
# peak_index 1874 peak_pressure 141576.23438
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P25.xlsx peak_time 0.0239798333
# cell_time 0.02397983335
# peak_index 2400 peak_pressure 132282.98438
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P29.xlsx peak_time 0.029379731
# cell_time 0.029379731044
# peak_index 2940 peak_pressure 126126
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P33.xlsx peak_time 0.0348798931
# cell_time 0.034879893064
# peak_index 3490 peak_pressure 121407.83594
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P37.xlsx peak_time 0.0404497683
# cell_time 0.040449768305
# peak_index 4047 peak_pressure 118445.08594
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P41.xlsx peak_time 0.0460698083
# cell_time 0.046069808304
# peak_index 4609 peak_pressure 115909.44531
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P45.xlsx peak_time 0.0517397299
# cell_time 0.051739729941
# peak_index 5176 peak_pressure 114521.25781
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P49.xlsx peak_time 0.0574598797
# cell_time 0.057459879667
# peak_index 5748 peak_pressure 112635.39844
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P5.xlsx peak_time 0.0017797805
# cell_time 0.0017797804903
# peak_index 180 peak_pressure 789798.5625
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P53.xlsx peak_time 0.0632098839
# cell_time 0.063209883869
# peak_index 6323 peak_pressure 111399.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P57.xlsx peak_time 0.068929702
# cell_time 0.068929702044
# peak_index 6895 peak_pressure 110898.44531
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P59.xlsx peak_time 0.0718197972
# cell_time 0.071819797158
# peak_index 7184 peak_pressure 110134.96094
# file Pressure_curves_excel_with_MinMaxTime\L13_39\P9.xlsx peak_time 0.0048199431
# cell_time 0.0048199431039
# peak_index 484 peak_pressure 293844.25
# folder Pressure_curves_excel_with_MinMaxTime\L13_41
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P1.xlsx peak_time 0.0002599181
# cell_time 0.00025991807343
# peak_index 28 peak_pressure 6172120
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P13.xlsx peak_time 0.0088397339
# cell_time 0.0088397338986
# peak_index 886 peak_pressure 196894.42188
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P17.xlsx peak_time 0.0135197546
# cell_time 0.013519754633
# peak_index 1354 peak_pressure 160887.45312
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P21.xlsx peak_time 0.0185499303
# cell_time 0.018549930304
# peak_index 1857 peak_pressure 142467.48438
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P25.xlsx peak_time 0.023809785
# cell_time 0.023809785023
# peak_index 2383 peak_pressure 132418.23438
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P29.xlsx peak_time 0.0291999206
# cell_time 0.029199920595
# peak_index 2922 peak_pressure 125982.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P33.xlsx peak_time 0.0346697532
# cell_time 0.034669753164
# peak_index 3469 peak_pressure 122402.39844
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P37.xlsx peak_time 0.0402299836
# cell_time 0.040229983628
# peak_index 4025 peak_pressure 119228.22656
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P41.xlsx peak_time 0.0458499081
# cell_time 0.045849908143
# peak_index 4587 peak_pressure 116366.21875
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P45.xlsx peak_time 0.0515098572
# cell_time 0.051509857178
# peak_index 5153 peak_pressure 114762.96875
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P49.xlsx peak_time 0.0572197177
# cell_time 0.057219717652
# peak_index 5724 peak_pressure 112902.33594
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P5.xlsx peak_time 0.0017498268
# cell_time 0.001749826828
# peak_index 177 peak_pressure 826491.4375
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P53.xlsx peak_time 0.0629298016
# cell_time 0.062929801643
# peak_index 6295 peak_pressure 112162.52344
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P57.xlsx peak_time 0.0686797276
# cell_time 0.068679727614
# peak_index 6870 peak_pressure 111131.46094
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P59.xlsx peak_time 0.0715596974
# cell_time 0.07155969739
# peak_index 7158 peak_pressure 110438.85156
# file Pressure_curves_excel_with_MinMaxTime\L13_41\P9.xlsx peak_time 0.0047499025
# cell_time 0.0047499025241
# peak_index 477 peak_pressure 300615.0625
# folder Pressure_curves_excel_with_MinMaxTime\L13_43
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P1.xlsx peak_time 0.0002599811
# cell_time 0.00025998111232
# peak_index 28 peak_pressure 6508259.5
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P13.xlsx peak_time 0.0087297577
# cell_time 0.0087297577411
# peak_index 875 peak_pressure 200089.26562
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P17.xlsx peak_time 0.0133898659
# cell_time 0.013389865868
# peak_index 1341 peak_pressure 161876.75
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P21.xlsx peak_time 0.0183997341
# cell_time 0.01839973405
# peak_index 1842 peak_pressure 143832.70312
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P25.xlsx peak_time 0.023639733
# cell_time 0.023639732972
# peak_index 2366 peak_pressure 133205.53125
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P29.xlsx peak_time 0.0289997905
# cell_time 0.028999790549
# peak_index 2902 peak_pressure 127337.89844
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P33.xlsx peak_time 0.0344898179
# cell_time 0.034489817917
# peak_index 3451 peak_pressure 122209.58594
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P37.xlsx peak_time 0.0400397964
# cell_time 0.040039796382
# peak_index 4006 peak_pressure 118994.28906
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P41.xlsx peak_time 0.0456498489
# cell_time 0.045649848878
# peak_index 4567 peak_pressure 116567.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P45.xlsx peak_time 0.0512898862
# cell_time 0.051289886236
# peak_index 5131 peak_pressure 115209.49219
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P49.xlsx peak_time 0.0569798909
# cell_time 0.056979890913
# peak_index 5700 peak_pressure 113648.77344
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P5.xlsx peak_time 0.0017297176
# cell_time 0.0017297175946
# peak_index 175 peak_pressure 843974.25
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P53.xlsx peak_time 0.0626997873
# cell_time 0.062699787319
# peak_index 6272 peak_pressure 112401.05469
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P57.xlsx peak_time 0.0684799924
# cell_time 0.068479992449
# peak_index 6850 peak_pressure 110868.36719
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P59.xlsx peak_time 0.0713298768
# cell_time 0.071329876781
# peak_index 7135 peak_pressure 110479.99219
# file Pressure_curves_excel_with_MinMaxTime\L13_43\P9.xlsx peak_time 0.0046798759
# cell_time 0.004679875914
# peak_index 470 peak_pressure 308354.25
# folder Pressure_curves_excel_with_MinMaxTime\L13_45
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P1.xlsx peak_time 0.0002599426
# cell_time 0.00025994263706
# peak_index 28 peak_pressure 6465490.5
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P13.xlsx peak_time 0.0086298343
# cell_time 0.0086298342794
# peak_index 865 peak_pressure 203203
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P17.xlsx peak_time 0.0132598253
# cell_time 0.013259825297
# peak_index 1328 peak_pressure 163508.84375
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P21.xlsx peak_time 0.0182597358
# cell_time 0.018259735778
# peak_index 1828 peak_pressure 144640.125
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P25.xlsx peak_time 0.0234598164
# cell_time 0.023459816352
# peak_index 2348 peak_pressure 134105.3125
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P29.xlsx peak_time 0.0288198609
# cell_time 0.028819860891
# peak_index 2884 peak_pressure 127430.99219
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P33.xlsx peak_time 0.0342797041
# cell_time 0.034279704094
# peak_index 3430 peak_pressure 122950.80469
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P37.xlsx peak_time 0.039839711
# cell_time 0.03983971104
# peak_index 3986 peak_pressure 119402.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P41.xlsx peak_time 0.0454399139
# cell_time 0.045439913869
# peak_index 4546 peak_pressure 116917.53906
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P45.xlsx peak_time 0.0510699004
# cell_time 0.051069900393
# peak_index 5109 peak_pressure 115089.11719
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P49.xlsx peak_time 0.0567599237
# cell_time 0.056759923697
# peak_index 5678 peak_pressure 113518.53906
# file Pressure_curves_excel_with_MinMaxTime\L13_45\P5.xlsx peak_time 0.0016998891
# cell_time 0.0016998890787
# peak_index 172 peak_pressure 886900.1875
# ...
# cell_time 0.027459811419
# peak_index 2748 peak_pressure 133156.42188
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P33.xlsx peak_time 0.0328398868
# cell_time 0.032839886844
# peak_index 3286 peak_pressure 127540.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P37.xlsx peak_time 0.0383098312
# cell_time 0.038309831172
# peak_index 3833 peak_pressure 123433.42969
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P41.xlsx peak_time 0.0438499041
# cell_time 0.04384990409
# peak_index 4387 peak_pressure 120138.64844
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P45.xlsx peak_time 0.0494399853
# cell_time 0.049439985305
# peak_index 4946 peak_pressure 118001.58594
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P49.xlsx peak_time 0.0550799258
# cell_time 0.055079925805
# peak_index 5510 peak_pressure 115533.97656
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P5.xlsx peak_time 0.0015399298
# cell_time 0.0015399297699
# peak_index 156 peak_pressure 1138461.25
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P53.xlsx peak_time 0.0607499331
# cell_time 0.060749933124
# peak_index 6077 peak_pressure 114346.67969
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P57.xlsx peak_time 0.0664498582
# cell_time 0.066449858248
# peak_index 6647 peak_pressure 113241.24219
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P59.xlsx peak_time 0.0693097562
# cell_time 0.06930975616
# peak_index 6933 peak_pressure 112703.22656
# file Pressure_curves_excel_with_MinMaxTime\L13_63\P9.xlsx peak_time 0.0041499878
# cell_time 0.004149987828
# peak_index 417 peak_pressure 382771.5
# folder Pressure_curves_excel_with_MinMaxTime\L13_65
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P1.xlsx peak_time 0.000239941
# cell_time 0.00023994097137
# peak_index 26 peak_pressure 7826052.5
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P13.xlsx peak_time 0.0078097815
# cell_time 0.0078097814694
# peak_index 783 peak_pressure 234308.75
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P17.xlsx peak_time 0.0122099519
# cell_time 0.012209951878
# peak_index 1223 peak_pressure 179922
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P21.xlsx peak_time 0.0170299392
# cell_time 0.017029939219
# peak_index 1705 peak_pressure 155105.5
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P25.xlsx peak_time 0.0220999997
# cell_time 0.022099999711
# peak_index 2212 peak_pressure 141438.26562
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P29.xlsx peak_time 0.0273299366
# cell_time 0.027329936624
# peak_index 2735 peak_pressure 133313.17188
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P33.xlsx peak_time 0.0326999128
# cell_time 0.032699912786
# peak_index 3272 peak_pressure 127222.17969
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P37.xlsx peak_time 0.0381798074
# cell_time 0.038179807365
# peak_index 3820 peak_pressure 123064.89844
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P41.xlsx peak_time 0.0436997972
# cell_time 0.043699797243
# peak_index 4372 peak_pressure 120142.89844
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P45.xlsx peak_time 0.0492998734
# cell_time 0.049299873412
# peak_index 4932 peak_pressure 117649
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P49.xlsx peak_time 0.0549299121
# cell_time 0.05492991209
# peak_index 5495 peak_pressure 115776.46094
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P5.xlsx peak_time 0.0015298789
# cell_time 0.0015298789367
# peak_index 155 peak_pressure 1150534.625
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P53.xlsx peak_time 0.0605797768
# cell_time 0.060579776764
# peak_index 6060 peak_pressure 114642.55469
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P57.xlsx peak_time 0.0662797317
# cell_time 0.066279731691
# peak_index 6630 peak_pressure 113435.21094
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P59.xlsx peak_time 0.0691397339
# cell_time 0.069139733911
# peak_index 6916 peak_pressure 112669.77344
# file Pressure_curves_excel_with_MinMaxTime\L13_65\P9.xlsx peak_time 0.004109832
# cell_time 0.0041098319925
# peak_index 413 peak_pressure 389928.78125
# folder Pressure_curves_excel_with_MinMaxTime\L13_67
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P1.xlsx peak_time 0.0002399219
# cell_time 0.00023992185015
# peak_index 26 peak_pressure 8288154
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P13.xlsx peak_time 0.007749903
# cell_time 0.0077499030158
# peak_index 777 peak_pressure 236178.17188
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P17.xlsx peak_time 0.0121198846
# cell_time 0.012119884603
# peak_index 1214 peak_pressure 181687.35938
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P21.xlsx peak_time 0.0169098843
# cell_time 0.016909884289
# peak_index 1693 peak_pressure 157097.1875
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P25.xlsx peak_time 0.0219699591
# cell_time 0.02196995914
# peak_index 2199 peak_pressure 142445.25
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P29.xlsx peak_time 0.0272198394
# cell_time 0.027219839394
# peak_index 2724 peak_pressure 133406.57812
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P33.xlsx peak_time 0.0325797237
# cell_time 0.032579723746
# peak_index 3260 peak_pressure 127597
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P37.xlsx peak_time 0.0380197652
# cell_time 0.038019765168
# peak_index 3804 peak_pressure 124155.27344
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P41.xlsx peak_time 0.0435599424
# cell_time 0.043559942394
# peak_index 4358 peak_pressure 120310.52344
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P45.xlsx peak_time 0.0491297841
# cell_time 0.049129784107
# peak_index 4915 peak_pressure 118245.22656
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P49.xlsx peak_time 0.0547697544
# cell_time 0.05476975441
# peak_index 5479 peak_pressure 115990.94531
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P5.xlsx peak_time 0.0015199939
# cell_time 0.0015199938789
# peak_index 154 peak_pressure 1163971.25
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P53.xlsx peak_time 0.0604197048
# cell_time 0.060419704765
# peak_index 6044 peak_pressure 114483.16406
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P57.xlsx peak_time 0.0661098808
# cell_time 0.066109880805
# peak_index 6613 peak_pressure 113635.90625
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P59.xlsx peak_time 0.0689699873
# cell_time 0.068969987333
# peak_index 6899 peak_pressure 112575.39844
# file Pressure_curves_excel_with_MinMaxTime\L13_67\P9.xlsx peak_time 0.0040699095
# cell_time 0.0040699094534
# peak_index 409 peak_pressure 397257.59375
# folder Pressure_curves_excel_with_MinMaxTime\L13_69
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P1.xlsx peak_time 0.0002399478
# cell_time 0.00023994775256
# peak_index 26 peak_pressure 8260802.5
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P13.xlsx peak_time 0.0076799863
# cell_time 0.0076799863018
# peak_index 770 peak_pressure 239445.04688
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P17.xlsx peak_time 0.0120297829
# cell_time 0.012029782869
# peak_index 1205 peak_pressure 183641.875
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P21.xlsx peak_time 0.0168099161
# cell_time 0.016809916124
# peak_index 1683 peak_pressure 157412.65625
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P25.xlsx peak_time 0.0218598079
# cell_time 0.021859807894
# peak_index 2188 peak_pressure 142851.10938
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P29.xlsx peak_time 0.0270799734
# cell_time 0.02707997337
# peak_index 2710 peak_pressure 134250.60938
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P33.xlsx peak_time 0.0324297324
# cell_time 0.032429732382
# peak_index 3245 peak_pressure 128729.41406
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P37.xlsx peak_time 0.0378798097
# cell_time 0.037879809737
# peak_index 3790 peak_pressure 124304.03125
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P41.xlsx peak_time 0.0433998071
# cell_time 0.043399807066
# peak_index 4342 peak_pressure 121037.11719
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P45.xlsx peak_time 0.0489897616
# cell_time 0.048989761621
# peak_index 4901 peak_pressure 118146.41406
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P49.xlsx peak_time 0.0546099208
# cell_time 0.05460992083
# peak_index 5463 peak_pressure 116205.64844
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P5.xlsx peak_time 0.0014998675
# cell_time 0.0014998675324
# peak_index 152 peak_pressure 1218183.375
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P53.xlsx peak_time 0.0602697581
# cell_time 0.060269758105
# peak_index 6029 peak_pressure 114639.50781
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P57.xlsx peak_time 0.0659398213
# cell_time 0.065939821303
# peak_index 6596 peak_pressure 113447.05469
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P59.xlsx peak_time 0.0687998533
# cell_time 0.068799853325
# peak_index 6882 peak_pressure 113025.28906
# file Pressure_curves_excel_with_MinMaxTime\L13_69\P9.xlsx peak_time 0.00402983
# cell_time 0.0040298299864
# peak_index 405 peak_pressure 405085.90625
# folder Pressure_curves_excel_with_MinMaxTime\L13_7
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P1.xlsx peak_time 0.00038997
# cell_time 0.00038996999501
# peak_index 41 peak_pressure 2222090
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P13.xlsx peak_time 0.0126599995
# cell_time 0.012659999542
# peak_index 1268 peak_pressure 133762
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P17.xlsx peak_time 0.0180500001
# cell_time 0.018050000072
# peak_index 1807 peak_pressure 123268
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P21.xlsx peak_time 0.0236300007
# cell_time 0.023630000651
# peak_index 2365 peak_pressure 117443
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P25.xlsx peak_time 0.0292700008
# cell_time 0.029270000756
# peak_index 2929 peak_pressure 114092
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P29.xlsx peak_time 0.0349799991
# cell_time 0.034979999065
# peak_index 3500 peak_pressure 111998
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P33.xlsx peak_time 0.0407399982
# cell_time 0.040739998221
# peak_index 4076 peak_pressure 110347
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P37.xlsx peak_time 0.0465300009
# cell_time 0.046530000865
# peak_index 4655 peak_pressure 108856
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P41.xlsx peak_time 0.0523499995
# cell_time 0.052349999547
# peak_index 5237 peak_pressure 108086
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P45.xlsx peak_time 0.0581899993
# cell_time 0.058189999312
# peak_index 5821 peak_pressure 107215
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P49.xlsx peak_time 0.0640398785
# cell_time 0.064039878547
# peak_index 6406 peak_pressure 106625.72656
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P5.xlsx peak_time 0.0030596999
# cell_time 0.0030596998986
# peak_index 308 peak_pressure 268419
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P53.xlsx peak_time 0.0698999837
# cell_time 0.069899983704
# peak_index 6992 peak_pressure 106026.17969
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P57.xlsx peak_time 0.075779818
# cell_time 0.075779817998
# peak_index 7580 peak_pressure 105664.89844
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P59.xlsx peak_time 0.078719914
# cell_time 0.07871991396
# peak_index 7874 peak_pressure 105451.69531
# file Pressure_curves_excel_with_MinMaxTime\L13_7\P9.xlsx peak_time 0.0075297002
# cell_time 0.0075297001749
# peak_index 755 peak_pressure 159635
# folder Pressure_curves_excel_with_MinMaxTime\L13_70
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P1.xlsx peak_time 0.0002399929
# cell_time 0.0002399928635
# peak_index 26 peak_pressure 8233106.5
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P13.xlsx peak_time 0.0076499949
# cell_time 0.0076499949209
# peak_index 767 peak_pressure 240806.42188
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P17.xlsx peak_time 0.0119898142
# cell_time 0.011989814229
# peak_index 1201 peak_pressure 184159.04688
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P21.xlsx peak_time 0.0167598128
# cell_time 0.016759812832
# peak_index 1678 peak_pressure 157666.48438
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P25.xlsx peak_time 0.0218099635
# cell_time 0.021809963509
# peak_index 2183 peak_pressure 143190.59375
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P29.xlsx peak_time 0.0270297285
# cell_time 0.027029728517
# peak_index 2705 peak_pressure 134223.6875
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P33.xlsx peak_time 0.0323799439
# cell_time 0.032379943877
# peak_index 3240 peak_pressure 128166.36719
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P37.xlsx peak_time 0.0378097706
# cell_time 0.037809770554
# peak_index 3783 peak_pressure 124076.57031
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P41.xlsx peak_time 0.043339733
# cell_time 0.043339733034
# peak_index 4336 peak_pressure 120710.33594
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P45.xlsx peak_time 0.0488999523
# cell_time 0.048899952322
# peak_index 4892 peak_pressure 118368.74219
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P49.xlsx peak_time 0.0545299239
# cell_time 0.054529923946
# peak_index 5455 peak_pressure 116314.86719
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P5.xlsx peak_time 0.0014999149
# cell_time 0.0014999149134
# peak_index 152 peak_pressure 1205684.625
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P53.xlsx peak_time 0.0601698458
# cell_time 0.060169845819
# peak_index 6019 peak_pressure 115192.14844
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P57.xlsx peak_time 0.065859735
# cell_time 0.065859735012
# peak_index 6588 peak_pressure 113860.53906
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P59.xlsx peak_time 0.068709977
# cell_time 0.068709976971
# peak_index 6873 peak_pressure 113128.09375
# file Pressure_curves_excel_with_MinMaxTime\L13_70\P9.xlsx peak_time 0.0040099868
# cell_time 0.004009986762
# peak_index 403 peak_pressure 409020.71875
# folder Pressure_curves_excel_with_MinMaxTime\L13_9
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P1.xlsx peak_time 0.00036996
# cell_time 0.00036996000563
# peak_index 39 peak_pressure 2486120
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P13.xlsx peak_time 0.0121400002
# cell_time 0.012140000239
# peak_index 1216 peak_pressure 139422
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P17.xlsx peak_time 0.0174800009
# cell_time 0.017480000854
# peak_index 1750 peak_pressure 126701
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P21.xlsx peak_time 0.0229899995
# cell_time 0.022989999503
# peak_index 2301 peak_pressure 119868
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P25.xlsx peak_time 0.0285999998
# cell_time 0.028599999845
# peak_index 2862 peak_pressure 116154
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P29.xlsx peak_time 0.0342999995
# cell_time 0.034299999475
# peak_index 3432 peak_pressure 112944
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P33.xlsx peak_time 0.0400200002
# cell_time 0.04002000019
# peak_index 4004 peak_pressure 111361
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P37.xlsx peak_time 0.0457900017
# cell_time 0.04579000175
# peak_index 4581 peak_pressure 109859
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P41.xlsx peak_time 0.0516100004
# cell_time 0.051610000432
# peak_index 5163 peak_pressure 108594
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P45.xlsx peak_time 0.0573999994
# cell_time 0.05739999935
# peak_index 5742 peak_pressure 107839
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P49.xlsx peak_time 0.0632399395
# cell_time 0.063239939511
# peak_index 6326 peak_pressure 107292.28906
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P5.xlsx peak_time 0.0028398
# cell_time 0.0028397999704
# peak_index 286 peak_pressure 302001
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P53.xlsx peak_time 0.0690899789
# cell_time 0.069089978933
# peak_index 6911 peak_pressure 106685.08594
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P57.xlsx peak_time 0.0749596879
# cell_time 0.074959687889
# peak_index 7498 peak_pressure 106116.78906
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P59.xlsx peak_time 0.0778899193
# cell_time 0.077889919281
# peak_index 7791 peak_pressure 105965.99219
# file Pressure_curves_excel_with_MinMaxTime\L13_9\P9.xlsx peak_time 0.0071299998
# cell_time 0.007129999809
# peak_index 715 peak_pressure 169580

# %%
print (df1)
# Out:
#      Charge_mass Standoff_distance  Peak pressure  Peak time Peak index
# 0            0.5                 1   591827.62500    0.00067         69
# 1            0.5                 7   113668.39844    0.01588       1590
# 2            0.5                 9   110072.21094    0.02163       2165
# 3            0.5                11   107787.85156    0.02743       2745
# 4            0.5                13   106665.80469    0.03328       3330
# ..           ...               ...            ...        ...        ...
# 571          4.5                 3   302001.00000    0.00284        286
# 572          4.5                27   106685.08594    0.06909       6911
# 573          4.5                29   106116.78906    0.07496       7498
# 574          4.5                30   105965.99219    0.07789       7791
# 575          4.5                 5   169580.00000    0.00713        715
#
# [576 rows x 5 columns]

# %% [markdown]
# ## Create peak pressure excel file

# %%
with pd.ExcelWriter('Peak_Incident_Pressure_with_peak_index.xlsx', engine = "openpyxl", mode='a', if_sheet_exists='replace') as writer:  
    df1.to_excel(writer, sheet_name = "Sheet1", index = False, header = True)
