# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pandas as pd
import xlwings as xw
import openpyxl

# %% [markdown]
# ## Access input and output directories

# %%
#Access input folder
input_dir1 = Path ("Output")
print ("1",input_dir1)

#Access folders inside input folder
input_dir2 =  [folder for folder in input_dir1.iterdir() if folder.is_dir()]
print ("2",input_dir2)
# Out:
# 1 Output
# 2 [WindowsPath('Output/L803'), WindowsPath('Output/L804'), WindowsPath('Output/L806')]

# %% [markdown]
# ## Filtering arrival time

# %%
# Access each folder inside input folder
df = pd.DataFrame(columns = ['Charge_type', 'Charge_mass', 'Standoff_distance', 'Time_of_arrival'])
for folder in input_dir2:
    print ("folder", folder)
    
    # Make a list of data file names
    files = list(folder.rglob("*.xlsx"))
    
    #df = pd.DataFrame(columns = ['Charge_type', 'Charge_mass', 'Standoff_distance', 'Time_of_arrival'])
    for file in files:
        wrkbk = openpyxl.load_workbook(file)
        sh = wrkbk.active
        a=0
        # iterate through excel and display data
        for i in range(2, sh.max_row+1):
            cell_pressure = sh.cell (row = i, column = 2)
            if cell_pressure.value > 100000:
                print (file.stem)
                print ("pressure", cell_pressure.value)
                cell_time = sh.cell (row = i, column = 1)
                print ("time of arrival", cell_time.value)
                # append rows to an empty DataFrame
                new_row = {'Charge_type' : ['CompB'], 'Charge_mass' : [3], 'Standoff_distance' : [int(file.stem[1:])/2], 'Time_of_arrival' : [cell_time.value]}
                new_row_data = pd.DataFrame(new_row)
                df = pd.concat([df, new_row_data], ignore_index = True)
                a=a+1
            if a == 1:
                break
# Out:
# folder Output\L803
# T1
# pressure 100001
# time of arrival 0.00013461000344
# T10
# pressure 100001
# time of arrival 0.0087564997375
# T11
# pressure 100001
# time of arrival 0.010088999756
# T12
# pressure 100001
# time of arrival 0.011443999596
# T13
# pressure 100001
# time of arrival 0.012815999798
# T14
# pressure 100001
# time of arrival 0.014201999642
# T15
# pressure 100001
# time of arrival 0.015599999577
# T16
# pressure 100001
# time of arrival 0.017008999363
# T17
# pressure 100001
# time of arrival 0.018425999209
# T18
# pressure 100001
# time of arrival 0.019850999117
# T19
# pressure 100001
# time of arrival 0.021282000467
# T2
# pressure 100001
# time of arrival 0.00045369000873
# T20
# pressure 100001
# time of arrival 0.022718999535
# T21
# pressure 100001
# time of arrival 0.024160999805
# T22
# pressure 100001
# time of arrival 0.025606999174
# T23
# pressure 100001
# time of arrival 0.027057999745
# T24
# pressure 100001
# time of arrival 0.028511999175
# T25
# pressure 100001
# time of arrival 0.029969999567
# T26
# pressure 100001
# time of arrival 0.03143100068
# T27
# pressure 100001
# time of arrival 0.032894000411
# T28
# pressure 100001
# time of arrival 0.034359999001
# T29
# pressure 100001
# time of arrival 0.035828001797
# T3
# pressure 100001
# time of arrival 0.0009963499615
# T30
# pressure 100001
# time of arrival 0.037298001349
# T31
# pressure 100001
# time of arrival 0.038770001382
# T32
# pressure 100001
# time of arrival 0.04024399817
# T33
# pressure 100001
# time of arrival 0.041719000787
# T34
# pressure 100001
# time of arrival 0.043196998537
# T35
# pressure 100001
# time of arrival 0.044675000012
# T36
# pressure 100001
# time of arrival 0.046154998243
# T37
# pressure 100001
# time of arrival 0.047635998577
# T38
# pressure 100001
# time of arrival 0.049118999392
# T39
# pressure 100001
# time of arrival 0.050602998585
# T4
# pressure 100001
# time of arrival 0.001767699956
# T40
# pressure 100001
# time of arrival 0.052087001503
# T5
# pressure 100001
# time of arrival 0.0027175999712
# T6
# pressure 100001
# time of arrival 0.0037928998936
# T7
# pressure 100001
# time of arrival 0.0049549001269
# T8
# pressure 100001
# time of arrival 0.0061797001399
# T9
# pressure 100001
# time of arrival 0.0074506998062
# folder Output\L804
# T1
# pressure 100004
# time of arrival 0.00012709999282
# T10
# pressure 100001
# time of arrival 0.0083192000166
# T11
# pressure 100001
# time of arrival 0.0096262004226
# T12
# pressure 100001
# time of arrival 0.010958000086
# T13
# pressure 100001
# time of arrival 0.012308999896
# T14
# pressure 100001
# time of arrival 0.013677000068
# T15
# pressure 100001
# time of arrival 0.015058999881
# T16
# pressure 100001
# time of arrival 0.016452999786
# T17
# pressure 100001
# time of arrival 0.017855999991
# T18
# pressure 100001
# time of arrival 0.019268000498
# T19
# pressure 100001
# time of arrival 0.020687999204
# T2
# pressure 100001
# time of arrival 0.00041850999696
# T20
# pressure 100001
# time of arrival 0.022113999352
# T21
# pressure 100001
# time of arrival 0.02354599908
# T22
# pressure 100001
# time of arrival 0.02498300001
# T23
# pressure 100001
# time of arrival 0.02642500028
# T24
# pressure 100001
# time of arrival 0.027870999649
# T25
# pressure 100001
# time of arrival 0.02932099998
# T26
# pressure 100001
# time of arrival 0.030773999169
# T27
# pressure 100001
# time of arrival 0.032230000943
# T28
# pressure 100001
# time of arrival 0.033688999712
# T29
# pressure 100001
# time of arrival 0.035151001066
# T3
# pressure 100002
# time of arrival 0.00090609997278
# T30
# pressure 100001
# time of arrival 0.036614999175
# T31
# pressure 100001
# time of arrival 0.03808100149
# T32
# pressure 100001
# time of arrival 0.039549998939
# T33
# pressure 100001
# time of arrival 0.041019998491
# T34
# pressure 100001
# time of arrival 0.042491998523
# T35
# pressure 100001
# time of arrival 0.043965999037
# T36
# pressure 100001
# time of arrival 0.045441001654
# T37
# pressure 100001
# time of arrival 0.046918001026
# T38
# pressure 100001
# time of arrival 0.048395998776
# T39
# pressure 100001
# time of arrival 0.049874998629
# T4
# pressure 100001
# time of arrival 0.0016073000152
# T40
# pressure 100001
# time of arrival 0.051355998963
# T5
# pressure 100001
# time of arrival 0.002491600113
# T6
# pressure 100001
# time of arrival 0.0035093000624
# T7
# pressure 100001
# time of arrival 0.0046232999302
# T8
# pressure 100001
# time of arrival 0.0058071999811
# T9
# pressure 100001
# time of arrival 0.007043399848
# folder Output\L806
# T1
# pressure 100003
# time of arrival 0.0001176500009
# T10
# pressure 100001
# time of arrival 0.0076826000586
# T12
# pressure 100001
# time of arrival 0.010239999741
# T14
# pressure 100001
# time of arrival 0.012896000408
# T16
# pressure 100001
# time of arrival 0.015619999729
# T18
# pressure 100001
# time of arrival 0.018391000107
# T2
# pressure 100001
# time of arrival 0.00037531999988
# T20
# pressure 100001
# time of arrival 0.021199999377
# T22
# pressure 100001
# time of arrival 0.024036999792
# T24
# pressure 100001
# time of arrival 0.026895999908
# T26
# pressure 100001
# time of arrival 0.029774000868
# T28
# pressure 100001
# time of arrival 0.032666999847
# T30
# pressure 100001
# time of arrival 0.035571999848
# T32
# pressure 100001
# time of arrival 0.038488000631
# T34
# pressure 100001
# time of arrival 0.041413001716
# T36
# pressure 100001
# time of arrival 0.044346999377
# T38
# pressure 100001
# time of arrival 0.047286998481
# T4
# pressure 100002
# time of arrival 0.0014048999874
# T40
# pressure 100001
# time of arrival 0.050232999027
# T6
# pressure 100001
# time of arrival 0.0031202998944
# T8
# pressure 100001
# time of arrival 0.0052763000131

# %%
print (df)
# Out:
#     Charge_type Charge_mass  Standoff_distance  Time_of_arrival
# 0         CompB           3                0.5         0.000135
# 1         CompB           3                5.0         0.008756
# 2         CompB           3                5.5         0.010089
# 3         CompB           3                6.0         0.011444
# 4         CompB           3                6.5         0.012816
# ..          ...         ...                ...              ...
# 96        CompB           3               19.0         0.047287
# 97        CompB           3                2.0         0.001405
# 98        CompB           3               20.0         0.050233
# 99        CompB           3                3.0         0.003120
# 100       CompB           3                4.0         0.005276
#
# [101 rows x 4 columns]

# %%
df1 = df.drop(labels = 0, axis = "index")

# %%
print (df1)
# Out:
#     Charge_type Charge_mass  Standoff_distance  Time_of_arrival
# 1         CompB           3                5.0         0.008756
# 2         CompB           3                5.5         0.010089
# 3         CompB           3                6.0         0.011444
# 4         CompB           3                6.5         0.012816
# 5         CompB           3                7.0         0.014202
# ..          ...         ...                ...              ...
# 96        CompB           3               19.0         0.047287
# 97        CompB           3                2.0         0.001405
# 98        CompB           3               20.0         0.050233
# 99        CompB           3                3.0         0.003120
# 100       CompB           3                4.0         0.005276
#
# [100 rows x 4 columns]

# %%
with pd.ExcelWriter('Arrival_time.xlsx', engine = "openpyxl", mode='a', if_sheet_exists='replace') as writer:  
    df.to_excel(writer, sheet_name = "Sheet1", index = False, header = True)

# %%
print (int(file.stem[1:])/2)
# Out:
# 4.0
