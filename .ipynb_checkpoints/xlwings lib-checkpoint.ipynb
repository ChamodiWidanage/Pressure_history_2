# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pandas as pd
import xlwings as xw

# %% [markdown]
# ## Access input folders

# %%
#Access input folder
input_dir1 = Path ("Pressure_curves_ascii")
print ("1",input_dir1)

#Access folders inside input folder
input_dir2 =  [folder for folder in input_dir1.iterdir() if folder.is_dir()]
print ("2",input_dir2)
# Out:
# 1 Input
# 2 [WindowsPath('Input/L803'), WindowsPath('Input/L804'), WindowsPath('Input/L806')]

# %% [markdown]
# ## Create output files 1

# %%
# %%timeit -r1 -n1
# define current work directory
current_dir = Path.cwd()

# access the template to be used to generate files
excel_template = current_dir/ "Template.xlsx"

# Access each folder inside input folder
for folder in input_dir2:
    print ("folder", folder)
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
    
    # Make a set of file names
    keys = set (file.stem for file in files)
    
    # Use xlwings library to create excel files
    with xw.App (visible = False) as app:
        
        # for loop for keys
        for key in keys:
            
            # Open template excel file
            wb = app.books.open(excel_template)
            
            # for loop for files
            for file in files:
                if file.stem == key:
                    print ("file.stem = ", file.stem)
                    print ("key = ", key)
                    df = pd.read_csv(file, delimiter="\s+", skiprows = 8, skipfooter = 1, header = None, names = ["time", "pressure"])
                    wb.sheets[0].range("A1").options(index=False).value = df
            output_dir = current_dir/ "Pressure_curves_excel"
            output_dir.mkdir(exist_ok = True)
            output_dir1 = output_dir/ folder.stem
            output_dir1.mkdir(exist_ok = True)
            wb.save(output_dir1/f"{key}.xlsx")
        #print ("file",folder.stem, file.stem)
        #current_dir = Path.cwd()
        #excel_template = current_dir/ "Template.xlsx"
# Out:
# folder Input\L803
# file.stem =  T8
# key =  T8
# file.stem =  T14
# key =  T14
# file.stem =  T37
# key =  T37
# file.stem =  T38
# key =  T38
# file.stem =  T36
# key =  T36
# file.stem =  T9
# key =  T9
# file.stem =  T30
# key =  T30
# file.stem =  T5
# key =  T5
# file.stem =  T20
# key =  T20
# file.stem =  T12
# key =  T12
# file.stem =  T21
# key =  T21
# file.stem =  T3
# key =  T3
# file.stem =  T11
# key =  T11
# file.stem =  T18
# key =  T18
# file.stem =  T15
# key =  T15
# file.stem =  T4
# key =  T4
# file.stem =  T40
# key =  T40
# file.stem =  T22
# key =  T22
# file.stem =  T24
# key =  T24
# file.stem =  T1
# key =  T1
# file.stem =  T29
# key =  T29
# file.stem =  T23
# key =  T23
# file.stem =  T28
# key =  T28
# file.stem =  T13
# key =  T13
# file.stem =  T7
# key =  T7
# file.stem =  T17
# key =  T17
# file.stem =  T34
# key =  T34
# file.stem =  T39
# key =  T39
# file.stem =  T27
# key =  T27
# file.stem =  T35
# key =  T35
# file.stem =  T33
# key =  T33
# file.stem =  T19
# key =  T19
# file.stem =  T10
# key =  T10
# file.stem =  T2
# key =  T2
# file.stem =  T26
# key =  T26
# file.stem =  T25
# key =  T25
# file.stem =  T31
# key =  T31
# file.stem =  T32
# key =  T32
# file.stem =  T16
# key =  T16
# file.stem =  T6
# key =  T6
# folder Input\L804
# file.stem =  T8
# key =  T8
# file.stem =  T14
# key =  T14
# file.stem =  T37
# key =  T37
# file.stem =  T38
# key =  T38
# file.stem =  T36
# key =  T36
# file.stem =  T9
# key =  T9
# file.stem =  T30
# key =  T30
# file.stem =  T5
# key =  T5
# file.stem =  T20
# key =  T20
# file.stem =  T12
# key =  T12
# file.stem =  T21
# key =  T21
# file.stem =  T3
# key =  T3
# file.stem =  T11
# key =  T11
# file.stem =  T18
# key =  T18
# file.stem =  T15
# key =  T15
# file.stem =  T4
# key =  T4
# file.stem =  T40
# key =  T40
# file.stem =  T22
# key =  T22
# file.stem =  T24
# key =  T24
# file.stem =  T1
# key =  T1
# file.stem =  T29
# key =  T29
# file.stem =  T23
# key =  T23
# file.stem =  T28
# key =  T28
# file.stem =  T13
# key =  T13
# file.stem =  T7
# key =  T7
# file.stem =  T17
# key =  T17
# file.stem =  T34
# key =  T34
# file.stem =  T39
# key =  T39
# file.stem =  T27
# key =  T27
# file.stem =  T35
# key =  T35
# file.stem =  T33
# key =  T33
# file.stem =  T19
# key =  T19
# file.stem =  T10
# key =  T10
# file.stem =  T2
# key =  T2
# file.stem =  T26
# key =  T26
# file.stem =  T25
# key =  T25
# file.stem =  T31
# key =  T31
# file.stem =  T32
# key =  T32
# file.stem =  T16
# key =  T16
# file.stem =  T6
# key =  T6
# folder Input\L806
# file.stem =  T8
# key =  T8
# file.stem =  T14
# key =  T14
# file.stem =  T38
# key =  T38
# file.stem =  T36
# key =  T36
# file.stem =  T30
# key =  T30
# file.stem =  T20
# key =  T20
# file.stem =  T12
# key =  T12
# file.stem =  T18
# key =  T18
# file.stem =  T4
# key =  T4
# file.stem =  T40
# key =  T40
# file.stem =  T22
# key =  T22
# file.stem =  T24
# key =  T24
# file.stem =  T1
# key =  T1
# file.stem =  T28
# key =  T28
# file.stem =  T34
# key =  T34
# file.stem =  T26
# key =  T26
# file.stem =  T10
# key =  T10
# file.stem =  T2
# key =  T2
# file.stem =  T32
# key =  T32
# file.stem =  T16
# key =  T16
# file.stem =  T6
# key =  T6

# %% [markdown]
# ## Create output files 2

# %%
# Define current work directory
current_dir = Path.cwd()

# Access the template to be used to generate files
#excel_template = current_dir/ "Template.xlsx"

# Create output directory
#output_dir = current_dir/ "Pressure_curves_excel"
#output_dir.mkdir(exist_ok = True)

df = pd.DataFrame(columns = ['Folder', 'File', 'Min_time'])
print (df)

# Access each folder inside input folder
for folder in input_dir2:
    print ("folder", folder)
    
    # Make a list of data file names
    files = list(folder.rglob("*"))
    
    # Create output folders
    #output_dir1 = output_dir/ folder.stem
    #print ("output_dir1", output_dir1)
    #output_dir1.mkdir(exist_ok = True)
    
    # Initiate xlwings library
    with xw.App (visible = False) as app:
        
        # Access each file 
        for file in files:
            print ("file", file)
            
            # Open excel template
            wb = app.books.open(excel_template)
            
            # Create a dataframe out of data files and use delimiters
            df1 = pd.read_csv(file,
                             delimiter="\s+",
                             skiprows = 6,
                             nrows= 1,
                             engine = 'python',
                             header = None)
            
            # append rows to an empty DataFrame
            new_row = {'Folder' : [folder.stem], 'File' : [file.stem], 'Min_time' : [df1.iloc[0,5]]}
            new_row_data = pd.DataFrame(new_row)
            df = pd.concat([df, new_row_data], ignore_index = True)
print (df)
            # Write dataframe in excel template
            #wb.sheets[0].range("A1").options(index=False).value = df
            
            #file_name = file.stem
            #print ("file_name",file_name)
            
            # Create files in output directory
            #wb.save(output_dir1/f"{file_name}.xlsx")
# Out:
# Empty DataFrame
# Columns: [Folder, File, Min_time]
# Index: []
# folder Input\L803
# file Input\L803\T1
# file Input\L803\T2
# file Input\L803\T3
# file Input\L803\T4
# file Input\L803\T5
# folder Input\L804
# file Input\L804\T1
# file Input\L804\T2
# file Input\L804\T3
# file Input\L804\T4
# file Input\L804\T5
# file Input\L804\T6
# folder Input\L806
# file Input\L806\T1
# file Input\L806\T2
# file Input\L806\T4
# file Input\L806\T6
# file Input\L806\T8
#    Folder File  Min_time
# 0    L803   T1  0.001073
# 1    L803   T2  0.002319
# 2    L803   T3  0.003408
# 3    L803   T4  0.004953
# 4    L803   T5  0.006656
# 5    L804   T1  0.001239
# 6    L804   T2  0.002397
# 7    L804   T3  0.003333
# 8    L804   T4  0.004788
# 9    L804   T5  0.006454
# 10   L804   T6  0.008183
# 11   L806   T1  0.001493
# 12   L806   T2  0.001579
# 13   L806   T4  0.004593
# 14   L806   T6  0.007860
# 15   L806   T8  0.011294

# %%
with pd.ExcelWriter('Min_time.xlsx', engine = "openpyxl", mode='a', if_sheet_exists='replace') as writer:  
    df.to_excel(writer, sheet_name = "Sheet1", index = False, header = True)
