# %% [markdown]
# ## Import libraries

# %%
from pathlib import Path
import pandas as pd
import openpyxl
import math

# %% [markdown]
# ## Create "Arrival_end_times" excel file

# %%
# Open Arrival_end_times excel file
Table_file1 = openpyxl.load_workbook("Arrival_end_times.xlsx")
arr_table = Table_file1.active

# Define new columns for end time data
arr_table.cell(row = 1, column = 5).value = "End_time"
arr_table.cell(row = 1, column = 6).value = "End_index"

# %% [markdown]
# ## Open End_time excel file as a dataframe

# %%
end_df = pd.read_excel("End_time.xlsx")

# %%
end_df.head(5)
# Out:
#    Charge_mass  Standoff_distance  End_time  End_index
# 0          0.5                  1   0.01104       1106
# 1          0.5                  7   0.02850       2852
# 2          0.5                  9   0.03447       3449
# 3          0.5                 11   0.04046       4048
# 4          0.5                 13   0.04644       4646

# %% [markdown]
# ## Write end time data into Arrival_end_times excel file

# %%
for i in range(2, arr_table.max_row+1):
    for j in end_df.index:
        if arr_table.cell(row = i, column = 1).value == end_df["Charge_mass"][j]:
            if arr_table.cell(row = i, column = 2).value == end_df["Standoff_distance"][j]:
                arr_table.cell(row = i, column = 5). value = end_df["End_time"][j]
                arr_table.cell(row = i, column = 6). value = end_df["End_index"][j]
                end_df_T = end_df.T
                end_df_T.pop(j)
                end_df = end_df_T.T
                break
Table_file1.save("Arrival_end_times.xlsx")

# %% [markdown]
# ## Access input and output files

# %%
#Access input folder
input_dir1 = Path ("Pressure_curves_excel_with_MinTime")
print ("input",input_dir1)

#Access output directory
output_dir1 = Path ("Pressure_profiles")
output_dir1.mkdir(parents = True, exist_ok= True)
print ("output",output_dir1)
# Out:
# input Pressure_curves_excel_with_MinTime
# output Pressure_profiles

# %% [markdown]
# ## p_profile function to filter required pressure profile

# %%
def p_profile (file_path, arrival_index, end_index):
    excel_file = openpyxl.load_workbook(file_path)
    excel_sheet = excel_file.active
    
    p_time_history = []
    
    for row in excel_sheet.iter_rows(min_row=arrival_index,
                                     max_row=end_index,
                                     min_col=1, max_col=2,
                                     values_only=True):
        p_time_history.append (row)
    
    return p_time_history

# %% [markdown]
# ## Create pressure profile excel file

# %%
# Open file with arrival and end indexes
Table_file2 = openpyxl.load_workbook("Arrival_end_times.xlsx")
arr_end = Table_file2.active

# Create empty summary dataframe
summary = pd.DataFrame(columns = ["Folder_name", "File_name", "Datapoints_count"])

for k in range(2, arr_end.max_row+1):
    
    # Set folder name
    Charge_mass = arr_end.cell (row = k, column = 1).value
    fol_name = "L13_"+ str(int(Charge_mass*2))
    print (fol_name)
    
    # Find folder name in input_dir1
    input_dir2=next(input_dir1.glob(fol_name))
    print (input_dir2)
    
    # Create or find output folder name in output_dir1
    output_dir2 = Path(output_dir1/fol_name)
    output_dir2.mkdir(parents = True, exist_ok= True)
    
    # Set file name
    Standoff_dis = arr_end.cell (row = k, column = 2).value
    fil_name = "P"+str(int(Standoff_dis*2-1))+".xlsx"
    print (fil_name)
    
    # Find file name in folder
    file_path = next(input_dir2.glob(fil_name))
    print ("file_path", file_path)
    
    # Get arrival and end indexes
    arrival_index = arr_end.cell (row = k, column = 4).value
    end_index = arr_end.cell (row = k, column = 6).value
    
    arrival_time = arr_end.cell (row = k, column = 3).value
    end_time = arr_end.cell (row = k, column = 5).value
    
    print ("arrival_time", arrival_time)
    print ("end_time", end_time)
    
    # Get required pressure profile
    pressure_profile = p_profile (file_path, arrival_index, end_index)
    
    # Create dataframe with all data
    arr_end_df = pd.DataFrame( pressure_profile, columns = ["Time", "Pressure"])
    Charge_mass_column = [Charge_mass] * len(arr_end_df)
    Standoff_dis_column = [Standoff_dis] * len(arr_end_df)
    arr_end_df.insert(0, "Charge_mass", Charge_mass_column)
    arr_end_df.insert(1, "Standoff_distance", Standoff_dis_column)
    
    # Append summary dataframe
    dt_details = {"Folder_name" : [fol_name],
                  "File_name" : [fil_name],
                  "Datapoints_count" : [len(arr_end_df)]}
    dt_details_row = pd.DataFrame(dt_details)
    summary = pd.concat([summary, dt_details_row], ignore_index = True)
    
    # Write pressure profile to a new excel file
    excel_file = output_dir2/f"{fil_name}"
    with pd.ExcelWriter(excel_file, engine='openpyxl') as writer:
        arr_end_df.to_excel(writer, sheet_name = 'Sheet1', index = False, header = True)
# Out:
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P1.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P1.xlsx
# arrival_time 0.00065974111203
# end_time 0.011039755307
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P13.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P13.xlsx
# arrival_time 0.015829598531
# end_time 0.028499947861
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P17.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P17.xlsx
# arrival_time 0.021559743211
# end_time 0.034469928592
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P21.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P21.xlsx
# arrival_time 0.027349645272
# end_time 0.040459807962
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P25.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P25.xlsx
# arrival_time 0.033179961145
# end_time 0.046439867467
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P29.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P29.xlsx
# arrival_time 0.039039634168
# end_time 0.052429836243
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P33.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P33.xlsx
# arrival_time 0.044919606298
# end_time 0.058419886976
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P37.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P37.xlsx
# arrival_time 0.050809942186
# end_time 0.064399704337
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P41.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P41.xlsx
# arrival_time 0.056709840894
# end_time 0.070389844477
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P45.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P45.xlsx
# arrival_time 0.06261972338
# end_time 0.076379992068
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P49.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P49.xlsx
# arrival_time 0.068539969623
# end_time 0.082359857857
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P5.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P5.xlsx
# arrival_time 0.0048697311431
# end_time 0.016599819064
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P53.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P53.xlsx
# arrival_time 0.074459858239
# end_time 0.088349618018
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P57.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P57.xlsx
# arrival_time 0.080389663577
# end_time 0.094339795411
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P59.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P59.xlsx
# arrival_time 0.083349645138
# end_time 0.097329743207
# L13_1
# Pressure_curves_excel_with_MinTime\L13_1
# P9.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_1\P9.xlsx
# arrival_time 0.010209808126
# end_time 0.022529779002
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P1.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P1.xlsx
# arrival_time 0.00033997470746
# end_time 0.024709748104
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P13.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P13.xlsx
# arrival_time 0.011699769646
# end_time 0.037799991667
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P17.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P17.xlsx
# arrival_time 0.016969731078
# end_time 0.043699923903
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P21.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P21.xlsx
# arrival_time 0.022419843823
# end_time 0.0496397838
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P25.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P25.xlsx
# arrival_time 0.027999697253
# end_time 0.055589761585
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P29.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P29.xlsx
# arrival_time 0.033639710397
# end_time 0.061559796333
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P33.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\P33.xlsx
# arrival_time 0.039349745959
# end_time 0.067529991269
# L13_11
# Pressure_curves_excel_with_MinTime\L13_11
# P37.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_11\
# L13_7
# Pressure_curves_excel_with_MinTime\L13_7
# P59.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_7\P59.xlsx
# arrival_time 0.078639999032
# end_time 0.10409992188
# L13_7
# Pressure_curves_excel_with_MinTime\L13_7
# P9.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_7\P9.xlsx
# arrival_time 0.0075098997913
# end_time 0.0295199994
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P1.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P1.xlsx
# arrival_time 0.0002399928635
# end_time 0.047109816223
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P13.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P13.xlsx
# arrival_time 0.007629962638
# end_time 0.052769977599
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P17.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P17.xlsx
# arrival_time 0.011969762854
# end_time 0.058429777622
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P21.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P21.xlsx
# arrival_time 0.016729809344
# end_time 0.064219847322
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P25.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P25.xlsx
# arrival_time 0.021769808605
# end_time 0.070079758763
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P29.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P29.xlsx
# arrival_time 0.026979796588
# end_time 0.075969725847
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P33.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P33.xlsx
# arrival_time 0.032329827547
# end_time 0.081879928708
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P37.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P37.xlsx
# arrival_time 0.037769708782
# end_time 0.087809823453
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P41.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P41.xlsx
# arrival_time 0.043279755861
# end_time 0.09374986589
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P45.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P45.xlsx
# arrival_time 0.048849996179
# end_time 0.099699743092
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P49.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P49.xlsx
# arrival_time 0.05445985496
# end_time 0.10565974563
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P5.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P5.xlsx
# arrival_time 0.0014899796806
# end_time 0.044079825282
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P53.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P53.xlsx
# arrival_time 0.060119993985
# end_time 0.11161977798
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P57.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P57.xlsx
# arrival_time 0.065799921751
# end_time 0.11757987738
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P59.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P59.xlsx
# arrival_time 0.068649999797
# end_time 0.12056986243
# L13_70
# Pressure_curves_excel_with_MinTime\L13_70
# P9.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_70\P9.xlsx
# arrival_time 0.0039999336004
# end_time 0.047509949654
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P1.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P1.xlsx
# arrival_time 0.00035993001075
# end_time 0.023199999705
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P13.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P13.xlsx
# arrival_time 0.012120000087
# end_time 0.036690000445
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P17.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P17.xlsx
# arrival_time 0.017449999228
# end_time 0.042599998415
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P21.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P21.xlsx
# arrival_time 0.02295999974
# end_time 0.048539999872
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P25.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P25.xlsx
# arrival_time 0.02855999954
# end_time 0.054499998689
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P29.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P29.xlsx
# arrival_time 0.03423999995
# end_time 0.060469999909
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P33.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P33.xlsx
# arrival_time 0.039969999343
# end_time 0.06644000113
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P37.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P37.xlsx
# arrival_time 0.045740000904
# end_time 0.07242000103
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P41.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P41.xlsx
# arrival_time 0.051529999822
# end_time 0.07840000093
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P45.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P45.xlsx
# arrival_time 0.057339999825
# end_time 0.08438000083
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P49.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P49.xlsx
# arrival_time 0.06317999959
# end_time 0.090379722416
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P5.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P5.xlsx
# arrival_time 0.0028299000114
# end_time 0.025180000812
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P53.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P53.xlsx
# arrival_time 0.06902000308
# end_time 0.096369914711
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P57.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P57.xlsx
# arrival_time 0.074879996479
# end_time 0.1023498401
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P59.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P59.xlsx
# arrival_time 0.077820003033
# end_time 0.10533998162
# L13_9
# Pressure_curves_excel_with_MinTime\L13_9
# P9.xlsx
# file_path Pressure_curves_excel_with_MinTime\L13_9\P9.xlsx
# arrival_time 0.0071099000052
# end_time 0.030829999596

# %% [markdown]
# ## Create Pressure_profile_summary file

# %%
with pd.ExcelWriter("Pressure_profile_summary.xlsx", engine='openpyxl') as writer:
    summary.to_excel(writer, sheet_name = 'Sheet1', index = False, header = True)
